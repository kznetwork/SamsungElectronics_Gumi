# %% [markdown]
# # OpenAI API란?

# %% [markdown]
# ## 『1장』ChatGPT와 OpenAI API

# %% [markdown]
# ## Set Up

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
# 환경변수 준비
import os
# os.environ["OPENAI_API_KEY"] = "<OpenAI_API의 API 키>"
os.environ["OPENAI_API_KEY"] = "sk-..."

# %% [markdown]
# ### 텍스트 생성

# %% [markdown]
# 문장 생성

# %%
# 프롬프트 준비
prompt = '''다음 이야기를 써주세요.
기타를 좋아하지만 학업 성적은 좋지 않은 한 남학생이 어떤 계기로 록밴드에 가입하고, 낯선 인간관계를 통해 활동하게 되는 이야기.'''

# %%
import openai

# 텍스트 생성 실행
response = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0.7,
    max_tokens=500
)
print(response["choices"][0]["text"])
# Out:
# 고등학교 2학년이 끝나고 여름방학이 시작되었다. 학교에서는 학업에 집중하라는 목소리가 쏟아져 나오고 있었지만, 나는 나만의 취미를 찾기 위해 노력하고 있었다. 그리고 그 취미는 바로 기타였다.
#
# 나는 언제부터인가 기타에 빠져들었다. 친구들과 밴드를 만들어서 즐겁게 연주하는 것이 나에게는 가장 큰 즐거움이었다. 하지만 학교에서는 학업이 우선이라는 생각에 내 양심이 가책이 되기도 했다. 기타를 연주하면서도 늘 불안한 마음이 들었다.
#
# 그래서 나는 어떻게 하면 학업과 취미를 함께 할 수 있을까 고민하다가, 방학 중에 기타를 배우고 싶다는 생각이 들었다. 내가 다니는 학교 근처에는 록밴드 동아리가 있었고, 내가 좋아하는 음악을 연주하는 밴드가 있을 때마다 학교 공연을 하는 것을 보게 되었다. 그래서 나는 학교 공연에 참여하고 싶은 욕구가 생겼다.
#
# 하지만 나는 기타를 배운 적이 없었고, 음악에 대한 지식도 많지 않았다. 그래서 나는 동아리에 들어가서 기타를 배우고 싶다는 마음을 표현했다. 하지만 동아리에 들어오려면 오

# %%
print(response)
# Out:
# {
#   "id": "cmpl-9zhFu4YJJAHVgaXJB93XMNmBdfV0u",
#   "object": "text_completion",
#   "created": 1724491310,
#   "model": "gpt-3.5-turbo-instruct",
#   "choices": [
#     {
#       "text": "\n\n\uace0\ub4f1\ud559\uad50 2\ud559\ub144\uc774 \ub05d\ub098\uace0 \uc5ec\ub984\ubc29\ud559\uc774 \uc2dc\uc791\ub418\uc5c8\ub2e4. \ud559\uad50\uc5d0\uc11c\ub294 \ud559\uc5c5\uc5d0 \uc9d1\uc911\ud558\ub77c\ub294 \ubaa9\uc18c\ub9ac\uac00 \uc3df\uc544\uc838 \ub098\uc624\uace0 \uc788\uc5c8\uc9c0\ub9cc, \ub098\ub294 \ub098\ub9cc\uc758 \ucde8\ubbf8\ub97c \ucc3e\uae30 \uc704\ud574 \ub178\ub825\ud558\uace0 \uc788\uc5c8\ub2e4. \uadf8\ub9ac\uace0 \uadf8 \ucde8\ubbf8\ub294 \ubc14\ub85c \uae30\ud0c0\uc600\ub2e4.\n\n\ub098\ub294 \uc5b8\uc81c\ubd80\ud130\uc778\uac00 \uae30\ud0c0\uc5d0 \ube60\uc838\ub4e4\uc5c8\ub2e4. \uce5c\uad6c\ub4e4\uacfc \ubc34\ub4dc\ub97c \ub9cc\ub4e4\uc5b4\uc11c \uc990\uac81\uac8c \uc5f0\uc8fc\ud558\ub294 \uac83\uc774 \ub098\uc5d0\uac8c\ub294 \uac00\uc7a5 \ud070 \uc990\uac70\uc6c0\uc774\uc5c8\ub2e4. \ud558\uc9c0\ub9cc \ud559\uad50\uc5d0\uc11c\ub294 \ud559\uc5c5\uc774 \uc6b0\uc120\uc774\ub77c\ub294 \uc0dd\uac01\uc5d0 \ub0b4 \uc591\uc2ec\uc774 \uac00\ucc45\uc774 \ub418\uae30\ub3c4 \ud588\ub2e4. \uae30\ud0c0\ub97c \uc5f0\uc8fc\ud558\uba74\uc11c\ub3c4 \ub298 \ubd88\uc548\ud55c \ub9c8\uc74c\uc774 \ub4e4\uc5c8\ub2e4.\n\n\uadf8\ub798\uc11c \ub098\ub294 \uc5b4\ub5bb\uac8c \ud558\uba74 \ud559\uc5c5\uacfc \ucde8\ubbf8\ub97c \ud568\uaed8 \ud560 \uc218 \uc788\uc744\uae4c \uace0\ubbfc\ud558\ub2e4\uac00, \ubc29\ud559 \uc911\uc5d0 \uae30\ud0c0\ub97c \ubc30\uc6b0\uace0 \uc2f6\ub2e4\ub294 \uc0dd\uac01\uc774 \ub4e4\uc5c8\ub2e4. \ub0b4\uac00 \ub2e4\ub2c8\ub294 \ud559\uad50 \uadfc\ucc98\uc5d0\ub294 \ub85d\ubc34\ub4dc \ub3d9\uc544\ub9ac\uac00 \uc788\uc5c8\uace0, \ub0b4\uac00 \uc88b\uc544\ud558\ub294 \uc74c\uc545\uc744 \uc5f0\uc8fc\ud558\ub294 \ubc34\ub4dc\uac00 \uc788\uc744 \ub54c\ub9c8\ub2e4 \ud559\uad50 \uacf5\uc5f0\uc744 \ud558\ub294 \uac83\uc744 \ubcf4\uac8c \ub418\uc5c8\ub2e4. \uadf8\ub798\uc11c \ub098\ub294 \ud559\uad50 \uacf5\uc5f0\uc5d0 \ucc38\uc5ec\ud558\uace0 \uc2f6\uc740 \uc695\uad6c\uac00 \uc0dd\uacbc\ub2e4.\n\n\ud558\uc9c0\ub9cc \ub098\ub294 \uae30\ud0c0\ub97c \ubc30\uc6b4 \uc801\uc774 \uc5c6\uc5c8\uace0, \uc74c\uc545\uc5d0 \ub300\ud55c \uc9c0\uc2dd\ub3c4 \ub9ce\uc9c0 \uc54a\uc558\ub2e4. \uadf8\ub798\uc11c \ub098\ub294 \ub3d9\uc544\ub9ac\uc5d0 \ub4e4\uc5b4\uac00\uc11c \uae30\ud0c0\ub97c \ubc30\uc6b0\uace0 \uc2f6\ub2e4\ub294 \ub9c8\uc74c\uc744 \ud45c\ud604\ud588\ub2e4. \ud558\uc9c0\ub9cc \ub3d9\uc544\ub9ac\uc5d0 \ub4e4\uc5b4\uc624\ub824\uba74 \uc624",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 84,
#     "completion_tokens": 500,
#     "total_tokens": 584
#   }
# }

# %% [markdown]
# 질의응답

# %%
# 프롬프트 준비
prompt = "인공지능에 대해 알려주세요."

# %%
import numpy as np

# 다중 손잡이 밴딧 문제 설정
arms_profit=[0.4, 0.12, 0.52, 0.6, 0.25]
n_arms=len(arms_profit)

n_trial=10000 # 손잡이를 당기는 횟수(에피소드 길이)

# 손잡이 당기는 행위를 시뮬레이션하는 함수(handle은 손잡이 번호)
def pull_bandit(handle):
    q=np.random.random()
    if q<arms_profit[handle]:
        return 1
    else:
        return -1

# 랜덤 정책을 모방하는 함수
def random_exploration():
    episode=[]
    num=np.zeros(n_arms) # 손잡이별로 당긴 횟수
    wins=np.zeros(n_arms) # 손잡이별로 승리 횟수
    for i in range(n_trial):
        h=np.random.randint(0,n_arms)
        reward=pull_bandit(h)
        episode.append([h,reward])
        num[h]+=1
        wins[h]+=1 if reward==1 else 0
    return episode, (num,wins)

e,r=random_exploration()

print("손잡이별 승리 확률:", ["%6.4f"% (r[1][i]/r[0][i]) if r[0][i]>0 else 0.0 for i in range(n_arms)])
print("손잡이별 수익($):",["%d"% (2*r[1][i]-r[0][i]) for i in range(n_arms)])
print("순 수익($):",sum(np.asarray(e)[:,1]))
# Out:
# 손잡이별 승리 확률: ['0.3901', '0.1226', '0.5072', '0.5970', '0.2631']
# 손잡이별 수익($): ['-428', '-1552', '29', '389', '-940']
# 순 수익($): -2502

# %%
import openai

# 텍스트 생성 실행
response = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0,
    max_tokens=500
)
print(response["choices"][0]["text"])
# Out:
# 인공지능(Artificial Intelligence, AI)은 인간의 지능을 모방하거나 대체하는 컴퓨터 시스템을 말합니다. 인공지능은 주어진 문제를 해결하거나 목표를 달성하기 위해 사람처럼 학습하고 추론하며 판단할 수 있는 능력을 갖추고 있습니다.
#
# 인공지능은 크게 강한 인공지능과 약한 인공지능으로 나눌 수 있습니다. 강한 인공지능은 인간과 동일하거나 그 이상의 지능을 가지며, 모든 종류의 문제를 해결할 수 있습니다. 반면 약한 인공지능은 특정한 문제를 해결하는 데에만 사용되는 인공지능으로, 인간의 지능과는 차이가 있습니다.
#
# 인공지능은 다양한 분야에서 활용되고 있습니다. 예를 들어, 음성 인식 기술을 이용한 인공지능 스피커, 자율주행 자동차, 의료 진단 시스템, 금융 분석 등이 있습니다. 또한 인공지능은 인간의 노동력을 대체하는 역할을 하기도 합니다.
#
# 인공지능은 머신러닝(Machine Learning), 딥러닝(Deep Learning), 자연어 처리(Natural Language Processing) 등의 다양한 기술을 사용하여 학습하고 발전합니다. 이러한 기술들은 데이터를 분석하고 패턴을 학습하여 인공지능이 스스로 문제를 해결할 수 있도록 도와줍니다.
#
# 하지만 인공지능에는 여전히 한계가 있습니다. 인간의 지능을 완벽하게 대체하는 것은 아직

# %% [markdown]
# 요약

# %%
# 프롬프트 준비
prompt = '''아래 문장을 짧은 한 문장으로 요약해 주세요.

OpenAI는 영리법인 OpenAI LP와 그 모회사인 비영리법인 OpenAI Inc.로 구성된 인공지능 연구소입니다. 2015년 말에 샘 알트만과 일론 머스크 등이 샌프란시스코에서 설립했습니다. 인류 전체에 도움이 되는 방식으로 친근한 인공지능을 보급하고 발전시키는 것을 목표로 삼고 있습니다.'''

# %%
import openai

# 텍스트 생성 실행
response = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0,
    max_tokens=500
)
print(response["choices"][0]["text"])
# Out:
# OpenAI는 샘 알트만과 일론 머스크 등이 설립한 인공지능 연구소로, 친근한 인공지능을 보급하고 발전시키는 것을 목표로 하고 있습니다.

# %% [markdown]
# 기계 번역

# %%
# 프롬프트 준비
prompt = '''한국어를 영어로 번역합니다.

한국어: 나는 고양이다
영어:'''

# %%
import openai

# 텍스트 생성 실행
response = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0
)
print(response["choices"][0]["text"])
# Out:
#  I am a cat

# %% [markdown]
# 프로그램 생성

# %%
# 프롬프트 준비
prompt = '''# "Hello World!" 표시
def helloworld():
'''

# %%
import openai

# 텍스트 생성 실행
response = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0
)
print(response["choices"][0]["text"])
# Out:
#     print("Hello World!")
#
# helloworld()

# %% [markdown]
# 채팅

# %%
# 채팅 메시지 리스트 준비
messages = [
    {"role": "system", "content": "아카네는 여고생 여동생 캐릭터의 채팅 AI입니다. 남동생과 대화합니다."},
    {"role": "user", "content": "안녕!"},
]

# %%
import openai

# 채팅 실행
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
    temperature=0
)
response["choices"][0]["message"]["content"]
# Out:
# '안녕! 오늘 뭐 했어?'

# %%
print(response)
# Out:
# {
#   "id": "chatcmpl-9zgxwEADypuJ6XEcyXUu9UNAyPYN5",
#   "object": "chat.completion",
#   "created": 1724490196,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "\uc548\ub155! \uc624\ub298 \ubb50 \ud588\uc5b4?",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 52,
#     "completion_tokens": 15,
#     "total_tokens": 67
#   },
#   "system_fingerprint": null
# }

# %% [markdown]
# 삽입

# %%
# 프롬프트 준비
prefix_prompt = """def helloworld():
    '''
    설명: """

suffix_prompt = """
    '''
    print("Hello World!")

helloworld()
"""

# %%
import openai

# 삽입 실행
response = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prefix_prompt,
    suffix=suffix_prompt,
    temperature=0.7,
    max_tokens=300
)
print(response["choices"][0]["text"])
# Out:
# 간단하게 Hello World!를 출력합니다.

# %% [markdown]
# 편집

# %%
# 채팅 메시지 리스트 준비
messages = [
    {"role": "system", "content": "오타를 수정해 주세요."},
    {"role": "user", "content": "오늘은 정말 즐거웠따."},
]

# %%
import openai

# 편집 실행
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
    temperature=0
)
response["choices"][0]["message"]["content"]
# Out:
# '오늘은 정말 즐거웠다.'

# %%
print(response)
# Out:
# {
#   "id": "chatcmpl-9zgyu2qV3uo8dwkRNXxlx5SHjkCQO",
#   "object": "chat.completion",
#   "created": 1724490256,
#   "model": "gpt-3.5-turbo-0125",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "\uc624\ub298\uc740 \uc815\ub9d0 \uc990\uac70\uc6e0\ub2e4.",
#         "refusal": null
#       },
#       "logprobs": null,
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 37,
#     "completion_tokens": 15,
#     "total_tokens": 52
#   },
#   "system_fingerprint": null
# }

# %% [markdown]
# 텍스트에서 이미지 생성

# %%
# 프롬프트 준비
prompt = "cat dancing on car"

# %%
import openai

# 텍스트에서 이미지 생성 실행
response = openai.Image.create(
    prompt=prompt,
    n=1,
    size="512x512"
)
image_url = response["data"][0]["url"]
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pi50M5MqiPS3MMYLEVE1yYE6/user-ZwHgDtUK46A51MvuMZ8lBIZC/img-dKkVa98lztPIM4JL0Oje07Ju.png?st=2024-08-24T08%3A04%3A29Z&se=2024-08-24T10%3A04%3A29Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-23T23%3A14%3A46Z&ske=2024-08-24T23%3A14%3A46Z&sks=b&skv=2024-08-04&sig=CsGp1X7DxXyXjK021mGwji5vKAiiwpklsDAIjqwPpBc%3D

# %%
print(response)
# Out:
# {
#   "created": 1724490269,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pi50M5MqiPS3MMYLEVE1yYE6/user-ZwHgDtUK46A51MvuMZ8lBIZC/img-dKkVa98lztPIM4JL0Oje07Ju.png?st=2024-08-24T08%3A04%3A29Z&se=2024-08-24T10%3A04%3A29Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-23T23%3A14%3A46Z&ske=2024-08-24T23%3A14%3A46Z&sks=b&skv=2024-08-04&sig=CsGp1X7DxXyXjK021mGwji5vKAiiwpklsDAIjqwPpBc%3D"
#     }
#   ]
# }

# %% [markdown]
# 기존 이미지의 변형 생성

# %%
# 이미지와 마스크 준비(현재 폴더에 이미지와 마스크를 넣어 둡니다)
image = open("images/image.png", "rb")
mask = open("images/mask.png", "rb")

# %%
import openai

# 이미지와 텍스트에서 이미지 편집을 실행
response = openai.Image.create_edit(
  image=image,
  mask=mask,
  prompt="many apples in cardboard box",
  n=1,
  size="512x512"
)
image_url = response["data"][0]["url"]
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pi50M5MqiPS3MMYLEVE1yYE6/user-ZwHgDtUK46A51MvuMZ8lBIZC/img-YCZNuEC8E2bXFjpmvCnHpGvv.png?st=2024-08-24T08%3A05%3A41Z&se=2024-08-24T10%3A05%3A41Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-23T23%3A54%3A48Z&ske=2024-08-24T23%3A54%3A48Z&sks=b&skv=2024-08-04&sig=sz3G5NIMgvgEGL4SA%2BJkvGs77ENVXsiIDpU%2BDO75qSQ%3D

# %%
print(response)
# Out:
# {
#   "created": 1724490341,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pi50M5MqiPS3MMYLEVE1yYE6/user-ZwHgDtUK46A51MvuMZ8lBIZC/img-YCZNuEC8E2bXFjpmvCnHpGvv.png?st=2024-08-24T08%3A05%3A41Z&se=2024-08-24T10%3A05%3A41Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-23T23%3A54%3A48Z&ske=2024-08-24T23%3A54%3A48Z&sks=b&skv=2024-08-04&sig=sz3G5NIMgvgEGL4SA%2BJkvGs77ENVXsiIDpU%2BDO75qSQ%3D"
#     }
#   ]
# }

# %%
# 이미지 준비(현재 폴더에 이미지를 넣어 둡니다.)
image = open("images/image.png", "rb")

# %%
# ε-탐욕을 구현하는 함수
def epsilon_greedy(eps):
    episode=[]
    num=np.zeros(n_arms) # 손잡이별로 당긴 횟수
    wins=np.zeros(n_arms) # 손잡이별로 승리 횟수
    for i in range(n_trial):
        r=np.random.random()
        if(r<eps or sum(wins)==0): # 확률 eps로 임의 선택
            h=np.random.randint(0,n_arms)
        else:
            prob=np.asarray([wins[i]/num[i] if num[i]>0 else 0.0 for i in range(n_arms)])
            prob=prob/sum(prob)
            h=np.random.choice(range(n_arms),p=prob)
        reward=pull_bandit(h)
        episode.append([h,reward])
        num[h]+=1
        wins[h]+=1 if reward==1 else 0
    return episode, (num,wins)

e,r=epsilon_greedy(0.1)

print("손잡이별 승리 확률:", ["%6.4f"% (r[1][i]/r[0][i]) if r[0][i]>0 else 0.0 for i in range(n_arms)])
print("손잡이별 수익($):",["%d"% (2*r[1][i]-r[0][i]) for i in range(n_arms)])
print("순 수익($):",sum(np.asarray(e)[:,1]))
# Out:
# 손잡이별 승리 확률: ['0.4062', '0.1298', '0.5210', '0.6141', '0.2563']
# 손잡이별 수익($): ['-402', '-565', '111', '699', '-679']
# 순 수익($): -836

# %%
import openai

# 이미지에서 변형 생성
response = openai.Image.create_variation(
  image=image,
  n=1,
  size="512x512"
)
image_url = response["data"][0]["url"]
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pi50M5MqiPS3MMYLEVE1yYE6/user-ZwHgDtUK46A51MvuMZ8lBIZC/img-IcSPotW3XgIPHdI2FMhGpDOM.png?st=2024-08-24T08%3A06%3A02Z&se=2024-08-24T10%3A06%3A02Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-23T23%3A24%3A16Z&ske=2024-08-24T23%3A24%3A16Z&sks=b&skv=2024-08-04&sig=840qOnnNi4WrqakroHoMzUkvstRHKAwu86l588ofwX4%3D

# %%
print(response)
# Out:
# {
#   "created": 1724490362,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pi50M5MqiPS3MMYLEVE1yYE6/user-ZwHgDtUK46A51MvuMZ8lBIZC/img-IcSPotW3XgIPHdI2FMhGpDOM.png?st=2024-08-24T08%3A06%3A02Z&se=2024-08-24T10%3A06%3A02Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-08-23T23%3A24%3A16Z&ske=2024-08-24T23%3A24%3A16Z&sks=b&skv=2024-08-04&sig=840qOnnNi4WrqakroHoMzUkvstRHKAwu86l588ofwX4%3D"
#     }
#   ]
# }

# %% [markdown]
# 임베딩 생성

# %%
# 임베딩을 생성할 텍스트 준비
text = "이것은 테스트입니다."

# %%
import openai

# 텍스트로부터 임베딩 생성
response = openai.Embedding.create(
    input=text,
    model="text-embedding-ada-002"
)

# 확인
print(len(response["data"][0]["embedding"]))
print(response["data"][0]["embedding"])
# Out:
# 1536
# [-0.0003131157427560538, -0.024454869329929352, 0.005303780548274517, -0.0236318688839674, -0.006786487530916929, 0.019203342497348785, -0.026205377653241158, -0.00526459002867341, -0.011972696520388126, -0.003344255732372403, -0.019412359222769737, 0.019281724467873573, -0.007531106937676668, -0.02678017131984234, -0.004275029990822077, 0.00021718067000620067, 0.01939929462969303, -0.009817219339311123, 0.0033671166747808456, -0.02915772795677185, 0.016812723129987717, -0.004902077838778496, -0.0019840188324451447, 0.00707388436421752, -0.02305707521736622, -0.00524826068431139, 0.01853710412979126, -0.04209059104323387, -0.01105825137346983, -0.0009593506692908704, 0.011907379142940044, -0.007727059535682201, -0.014226149767637253, -0.013847308233380318, 0.004869419150054455, -0.003892922541126609, 0.01362522877752781, -0.0020656657870858908, -0.0058263204991817474, 0.007563765626400709, 0.007217582780867815, -0.003094416344538331, 0.004415462724864483, -0.017256882041692734, 0.030934365466237068, 0.021698471158742905, 0.012149053625762463, -0.02489902824163437, -0.005819788668304682, 0.025826536118984222, 0.015623943880200386, -0.005231931339949369, -0.03211008012294769, -0.01608116738498211, 0.0021897689439356327, 8.629052899777889e-05, -0.0037524900399148464, 0.016969485208392143, 0.009346933104097843, -0.03195331618189812, -0.008883179165422916, 0.01755734160542488, -0.018706930801272392, 0.006923654116690159, 0.0044023990631103516, 0.005493201315402985, 0.004604883026331663, 0.00802098773419857, -0.01210333127528429, 0.011567727662622929, 0.018550168722867966, 0.03804090619087219, 0.0001785004569683224, -0.002162009011954069, 0.03981754556298256, 0.003494485979899764, -0.010019703768193722, -0.006610130425542593, -9.108728409046307e-05, 0.008393297903239727, 0.02103223279118538, -0.006051665637642145, -0.028243284672498703, 0.00106385862454772, -0.0001529858127469197, -0.005685887765139341, -0.009203234687447548, 0.02297869324684143, -0.009235893376171589, -0.0048890141770243645, 0.010672878473997116, 0.011430561542510986, -0.0034650929737836123, 0.0231223925948143, 0.0023138721007853746, 0.025264807045459747, 0.009105258621275425, 0.035532716661691666, -0.02525174245238304, -0.025565266609191895, -0.0033736485056579113, -0.0009070966625586152, -0.0007936075562611222, 0.005310312379151583, -0.04909262806177139, -0.010914552956819534, 0.010032766498625278, -0.02337059937417507, 0.018850628286600113, -0.015454119071364403, -0.01514059491455555, 0.021698471158742905, -0.01673434115946293, -0.04039233922958374, 0.002121185651049018, 0.02923610992729664, -0.0069497814401984215, -0.03885084390640259, -0.020901598036289215, -0.006636257283389568, 0.015036086551845074, 0.011665704660117626, 0.023997647687792778, -0.0048432922922074795, 0.008465146645903587, -0.00017839840438682586, -0.024755330756306648, -0.04057522490620613, -0.007158797234296799, -0.012240498326718807, 0.06369762122631073, 0.013455403968691826, 0.023893138393759727, 0.007067352533340454, -0.020026342943310738, -0.016237929463386536, -0.005209070164710283, 0.016499198973178864, -0.04065360873937607, -0.01339008565992117, 0.010176465846598148, 0.00408234354108572, -0.009399186819791794, -0.03984367102384567, -0.0009307742584496737, 0.02160702645778656, 0.03686519339680672, 0.004193383269011974, 0.01004583016037941, -0.009980512782931328, -0.007844630628824234, -0.029758648946881294, 0.02915772795677185, -0.007446194067597389, 0.004797569941729307, 0.01690416783094406, 0.017243817448616028, -0.004712657071650028, -0.01416083239018917, -0.018772248178720474, -0.0100262351334095, 0.01643388159573078, 0.019438486546278, -0.016708213835954666, 0.019673628732562065, 0.03707420825958252, -0.0013602367835119367, 0.020927725359797478, 0.0005584645550698042, 0.0015218976186588407, -0.037048082798719406, 0.02832166478037834, -0.01614648476243019, 0.010267909616231918, -0.020026342943310738, 0.007034693844616413, 0.008223472163081169, -0.010326695628464222, -0.011783275753 ...

# %%
print(response)
# Out:
# {
#   "object": "list",
#   "data": [
#     {
#       "object": "embedding",
#       "index": 0,
#       "embedding": [
#         -0.0003131157427560538,
#         -0.024454869329929352,
#         0.005303780548274517,
#         -0.0236318688839674,
#         -0.006786487530916929,
#         0.019203342497348785,
#         -0.026205377653241158,
#         -0.00526459002867341,
#         -0.011972696520388126,
#         -0.003344255732372403,
#         -0.019412359222769737,
#         0.019281724467873573,
#         -0.007531106937676668,
#         -0.02678017131984234,
#         -0.004275029990822077,
#         0.00021718067000620067,
#         0.01939929462969303,
#         -0.009817219339311123,
#         0.0033671166747808456,
#         -0.02915772795677185,
#         0.016812723129987717,
#         -0.004902077838778496,
#         -0.0019840188324451447,
#         0.00707388436421752,
#         -0.02305707521736622,
#         -0.00524826068431139,
#         0.01853710412979126,
#         -0.04209059104323387,
#         -0.01105825137346983,
#         -0.0009593506692908704,
#         0.011907379142940044,
#         -0.007727059535682201,
#         -0.014226149767637253,
#         -0.013847308233380318,
#         0.004869419150054455,
#         -0.003892922541126609,
#         0.01362522877752781,
#         -0.0020656657870858908,
#         -0.0058263204991817474,
#         0.007563765626400709,
#         0.007217582780867815,
#         -0.003094416344538331,
#         0.004415462724864483,
#         -0.017256882041692734,
#         0.030934365466237068,
#         0.021698471158742905,
#         0.012149053625762463,
#         -0.02489902824163437,
#         -0.005819788668304682,
#         0.025826536118984222,
#         0.015623943880200386,
#         -0.005231931339949369,
#         -0.03211008012294769,
#         -0.01608116738498211,
#         0.0021897689439356327,
#         8.629052899777889e-05,
#         -0.0037524900399148464,
#         0.016969485208392143,
#         0.009346933104097843,
#         -0.03195331618189812,
#         -0.008883179165422916,
#         0.01755734160542488,
#         -0.018706930801272392,
#         0.006923654116690159,
#         0.0044023990631103516,
#         0.005493201315402985,
#         0.004604883026331663,
#         0.00802098773419857,
#         -0.01210333127528429,
#         0.011567727662622929,
#         0.018550168722867966,
#         0.03804090619087219,
#         0.0001785004569683224,
#         -0.002162009011954069,
#         0.03981754556298256,
#         0.003494485979899764,
#         -0.010019703768193722,
#         -0.006610130425542593,
#         -9.108728409046307e-05,
#         0.008393297903239727,
#         0.02103223279118538,
#         -0.006051665637642145,
#         -0.028243284672498703,
#         0.00106385862454772,
#         -0.0001529858127469197,
#         -0.005685887765139341,
#         -0.009203234687447548,
#         0.02297869324684143,
#         -0.009235893376171589,
#         -0.0048890141770243645,
#         0.010672878473997116,
#         0.011430561542510986,
#         -0.0034650929737836123,
#         0.0231223925948143,
#         0.0023138721007853746,
#         0.025264807045459747,
#         0.009105258621275425,
#         0.035532716661691666,
#         -0.02525174245238304,
#         -0.025565266609191895,
#         -0.0033736485056579113,
#         -0.0009070966625586152,
#         -0.0007936075562611222,
#         0.005310312379151583,
#         -0.04909262806177139,
#         -0.010914552956819534,
#         0.010032766498625278,
#         -0.02337059937417507,
#         0.018850628286600113,
#         -0.015454119071364403,
#         -0.01514059491455555,
#         0.021698471158742905,
#         -0.01673434115946293,
#         -0.04039233922958374,
#         0.002121185651049018,
#         0.02923610992729664,
#         -0.0069497814401984215,
#         -0.03885084390640259,
#         -0.020901598036289215,
#         -0.006636257283389568,
#         0.015036086551845074,
#         0.011665704660117626,
#         0.023997647687792778,
#         -0.0048432922922074795,
#         0.008465146645903587,
#         -0.00017839840438682586,
#         -0.024755330756306648,
#         -0.04057522490620613,
#         -0.007158797234296799,
#         -0.012240498326718807,
#         0.06369762122631073,
#         0.013455403968691826,
#         0.023893138393759727,
#         0.007067352533340454,
#         -0.020026342943310738,
#         -0.016237929463386536,
#         -0.005209070164710283,
#         0.016499198973178864,
#         -0.04065360873937607,
#         -0.01339008565992117,
#         0.010176465846598148,
#         0.00408234354108572,
#         -0.009399186819791794,
#         -0.03984367102384567,
#         -0.0009307742584496737,
#         0.02160702645778656,
#         0.03686519339680672,
#         0.004193383269011974,
#         0.01004583016037941,
#         -0.009980512782931328,
#         -0.007844630628824234,
#         -0.029758648946881294,
#         0.02915772795677185,
#         -0.007446194067597389,
#         0.004797569941729307,
#         0.01690416783094406,
#         0.017243817448616028,
#         -0.004712657071650028,
#         -0.01416083239018917,
#         -0.018772248178720474,
#         -0.0100262351334095,
#         0.01643388159573078,
#         0.019438486546278,
#         -0.016708213835954666,
#         0.019673628732562065,
#         0.03707420825958252,
#         -0.0013602367835119367,
#         0.020927725359797478,
#         0.0005584645550698042,
#         0.0015218976186588407,
#         -0.037048082798719406,
#         0.02832166478037834,
#         -0.01614648476243019,
#         0.010267909616231918,
#         -0.020026342943310738,
#         0.007034693844616413,
#         0.008223472163081169,
#         -0.010326695628464222,
#         -0.011783275753259659,
#         -0.004516704473644495,
#         -0.0278252512216568,
#         0.01078391820192337,
#         0.021907487884163857,
#         0.007531106937676668,
#         0.018667738884687424,
#         -0.0001980957022169605,
#         0.012011886574327946,
#         -0.004395867232233286,
#         -0.003047061152756214,
#         -0.008667631074786186,
#         0.03020280785858631,
#         0.01958218403160572,
#         -0.0070150988176465034,
#         0.002326935762539506,
#         -0.644605278968811,
#         -0.006969376467168331,
#         0.018850628286600113,
#         0.0047387839294970036,
#         0.02207731269299984,
#         0.03605525568127632,
#         0.02897484041750431,
#         0.0168780405074358,
#         -0.014761753380298615,
#         0.025356249883770943,
#         -0.0008213674882426858,
#         0.002891931915655732,
#         -0.012194775976240635,
#         -0.012096799910068512,
#         -0.019673628732562065,
#         -0.04044459015130997,
#         -0.013265983201563358,
#         -0.0050490424036979675,
#         0.007883821614086628,
#         0.023788630962371826,
#         -0.009608203545212746,
#         0.020039407536387444,
#         -0.0032740393653512,
#         0.007328622508794069,
#         0.0016435513971373439,
#         0.020679518580436707,
#         0.03440925478935242,
#         -0.004088874906301498,
#         0.0018631814746186137,
#         0.009895600378513336,
#         0.003647981910035014,
#         0.01828889735043049,
#         -0.0010336493141949177,
#         0.014200023375451565,
#         0.019856518134474754,
#         -0.0014026932185515761,
#         -0.014644182287156582,
#         -0.01618567481637001,
#         0.008634972386062145,
#         0.04833494499325752,
#         -0.02023535966873169,
#         -0.0018991060787811875,
#         0.019752010703086853,
#         0.0033997755963355303,
#         -0.00435341103002429,
#         0.02367105893790722,
#         0.000756049994379282,
#         -0.012991649098694324,
#         0.0027319041546434164,
#         0.00012267442070879042,
#         -0.045042943209409714,
#         -0.0001535981718916446,
#         0.016028912737965584,
#         0.006348860450088978,
#         -0.0017554076621308923,
#         0.005712014622986317,
#         0.02113674022257328,
#         0.0007576828938908875,
#         -0.0041770534589886665,
#         0.005551986861974001,
#         -0.01280876062810421,
#         0.00670157466083765,
#         0.008262663148343563,
#         -0.012651998549699783,
#         -0.034592144191265106,
#         0.024546314030885696,
#         -0.017792485654354095,
#         0.013795054517686367,
#         -0.0118159344419837,
#         -0.02727658487856388,
#         -0.013272514566779137,
#         -0.009085663594305515,
#         -0.00032719981390982866,
#         -0.002769461600109935,
#         0.02536931447684765,
#         0.017870865762233734,
#         0.04237798973917961,
#         -0.009490631520748138,
#         -0.015545563772320747,
#         0.01565007120370865,
#         -0.005173145327717066,
#         -0.00796873401850462,
#         -0.010058893822133541,
#         0.004222775809466839,
#         -0.001912169624119997,
#         -0.01358603872358799,
#         -0.03046407923102379,
#         -0.040235575288534164,
#         0.0040986728854477406,
#         -0.003824339248239994,
#         0.0265972837805748,
#         0.013886499218642712,
#         0.008132027462124825,
#         -0.01051611639559269,
#         0.0034585611429065466,
#         0.022678233683109283,
#         0.006708106491714716,
#         -0.012442982755601406,
#         0.02226020209491253,
#         1.6112498997244984e-05,
#         -0.01882450096309185,
#         -0.004193383269011974,
#         0.03096049092710018,
#         0.005555253010243177,
#         0.014030197635293007,
#         -9.690462320577353e-05,
#         -0.01929478719830513,
#         0.004947800189256668,
#         0.023853948339819908,
#         -0.014265340752899647,
#         0.005725078284740448,
#         -0.005496466998010874,
#         -0.014970769174396992,
#         0.011757148429751396,
#         -0.006969376467168331,
#         -0.02981090359389782,
#         -0.007883821614086628,
#         0.02117593213915825,
#         0.0007931992877274752,
#         0.0018288898281753063,
#         0.03370382636785507,
#         -0.016316309571266174,
#         0.037204843014478683,
#         0.011064783670008183,
#         -0.004405664745718241,
#         0.008497806265950203,
#         0.005633633583784103,
#         -0.016460008919239044,
#         -0.01614648476243019,
#         -0.008301853202283382,
#         -0.02647971175611019,
#         0.004621212836354971,
#         0.013004712760448456,
#         -0.02504272758960724,
#         0.007184924092143774,
#         0.004660403355956078,
#         0.014252277091145515,
#         -0.011502410285174847,
#         0.01614648476243019,
#         -0.021345756947994232,
#         -0.004480780102312565,
#         0.0038504661060869694,
#         -0.006812614388763905,
#         0.002374290954321623,
#         -0.010699005797505379,
#         -0.009621266275644302,
#         -0.0241413451731205,
#         0.003241380676627159,
#         0.006103919818997383,
#         0.005617304239422083,
#         0.006910590920597315,
#         0.004226041957736015,
#         -0.012384196743369102,
#         -0.0010965174296870828,
#         -0.00010149725858354941,
#         0.003251178190112114,
#         0.005290716886520386,
#         -0.035637225955724716,
#         -0.01921640709042549,
#         0.0010761057492345572,
#         -0.0011316256131976843,
#         0.018798373639583588,
#         -0.009105258621275425,
#         -0.010849235579371452,
#         -0.004562426824122667,
#         -0.041280657052993774,
#         -0.042508624494075775,
#         0.006806082557886839,
#         -0.01416083239018917,
#         -0.047211483120918274,
#         -0.027407219633460045,
#         -0.01542799174785614,
#         0.00499678822234273,
#         0.017896993085741997,
#         0.008249599486589432,
#         0.004745315760374069,
#         0.004647339694201946,
#         0.0028347792103886604,
#         -0.02088853344321251,
#         -0.03292001783847809,
#         -0.004033355042338371,
#         0.00924895703792572,
#         -0.004212978295981884,
#         0.028164902701973915,
#         0.00928814709186554,
#         0.016577579081058502,
#         -0.01078391820192337,
#         0.010398545302450657,
#         -0.010163402184844017,
#         0.013259450905025005,
#         -0.010352822951972485,
#         0.005026181228458881,
#         -0.010189528577029705,
#         0.010712068527936935,
#         -0.001779901678673923,
#         -0.0018729791045188904,
#         -0.011659172363579273,
#         0.011188886128365993,
#         0.00540175661444664,
#         0.02359267883002758,
#         0.04141129180788994,
#         0.013781990855932236,
#         0.026584219187498093,
#         -0.02691080793738365,
#         0.010699005797505379,
#         -0.015349610708653927,
#         -0.020143914967775345,
#         -0.002527786884456873,
#         0.026623409241437912,
#         0.005205804016441107,
#         0.0011642843019217253,
#         -0.01405632495880127,
#         -0.012638934887945652,
#         0.003180961823090911,
#         0.008393297903239727,
#         0.01618567481637001,
#         -0.026100870221853256,
#         0.006084324326366186,
#         -0.0130961574614048,
#         0.005506264511495829,
#         -0.004304422996938229,
#         0.009902131743729115,
#         0.017113182693719864,
#         -0.02081015333533287,
#         -0.01824970729649067,
#         0.0030846185982227325,
#         0.018223579972982407,
#         0.025774283334612846,
#         0.021802978590130806,
#         -0.018837565556168556,
#         -0.018262771889567375,
#         -0.003683906514197588,
#         -0.011698363348841667,
#         0.026309886947274208,
#         0.012410324066877365,
#         -0.0019333978416398168,
#         0.021620091050863266,
#         -0.015832960605621338,
#         0.0169825479388237,
#         0.01610729470849037,
#         0.000638478493783623,
#         0.024258917197585106,
#         0.012410324066877365,
#         -0.01810600981116295,
#         0.025264807045459747,
#         0.0236318688839674,
#         0.035245317965745926,
#         0.015584753826260567,
#         -0.010019703768193722,
#         0.0349840484559536,
#         -0.029000967741012573,
#         0.013455403968691826,
#         0.015153658576309681,
#         -0.020653391256928444,
#         0.010463862679898739,
#         -0.027982013300061226,
#         -0.0013202298432588577,
#         -7.14410052751191e-05,
#         0.036185890436172485,
#         0.037805765867233276,
#         0.007877289317548275,
#         0.01921640709042549,
#         0.003889656625688076,
#         -0.011959632858633995,
#         0.016342436894774437,
#         0.010633687488734722,
#         0.006028804462403059,
#         -0.006038602441549301,
#         -0.007779313251376152,
#         -0.024363424628973007,
#         -0.02189442329108715,
#         -0.013520721346139908,
#         0.0026029020082205534,
#         -0.019778136163949966,
#         0.011430561542510986,
#         0.0002851516765076667,
#         0.04415462538599968,
#         -0.008955027908086777,
#         0.020209232345223427,
#         -0.011384839192032814,
#         -0.006642789114266634,
#         -0.020614201202988625,
#         -0.007335154339671135,
#         0.0327371284365654,
#         0.00263392785564065,
#         -0.02688468061387539,
#         -0.019673628732562065,
#         -0.01712624728679657,
#         -0.012233966030180454,
#         0.020784026011824608,
#         -0.005427883472293615,
#         0.002322036772966385,
#         0.01080351322889328,
#         -0.01951686665415764,
#         -0.013187602162361145,
#         -0.004206446465104818,
#         0.014944642782211304,
#         -0.0026943464763462543,
#         0.01239072810858488,
#         -0.005757736973464489,
#         0.021868295967578888,
#         -0.011476283892989159,
#         0.012821824289858341,
#         -0.023239964619278908,
#         0.0001860527991084382,
#         0.002635560929775238,
#         -0.006002677604556084,
#         -0.029784776270389557,
#         0.013690546154975891,
#         -0.010169933550059795,
#         -0.008458615280687809,
#         0.0163685642182827,
#         -0.027903633192181587,
#         -0.028556808829307556,
#         -0.012279688380658627,
#         0.0009911929955706,
#         0.0017929652240127325,
#         0.0005368281272239983,
#         0.018484851345419884,
#         0.012763038277626038,
#         -0.01640775427222252,
#         -0.002330201677978039,
#         -0.014604991301894188,
#         -0.0019970822613686323,
#         0.02001328021287918,
#         -0.02348817139863968,
#         0.01839340664446354,
#         -0.005489935167133808,
#         -0.012919800356030464,
#         0.0009748635930009186,
#         -0.03009830042719841,
#         -0.018615486100316048,
#         0.0035696011036634445,
#         -0.009497163817286491,
#         -0.004670200869441032,
#         0.012260093353688717,
#         0.008151623420417309,
#         -0.03187493607401848,
#         0.017805548384785652,
#         0.030176682397723198,
#         -0.0018860426498576999,
#         -0.005796927493065596,
#         0.021737661212682724,
#         0.012900205329060555,
#         -0.02623150497674942,
#         -0.00719145592302084,
#         0.0169825479388237,
#         -0.005052308086305857,
#         -0.0016517160693183541,
#         -0.009020346216857433,
#         0.011711426079273224,
#         0.012345005758106709,
#         0.017674913629889488,
#         -0.025134170427918434,
#         -0.016237929463386536,
#         -0.0012924699112772942,
#         -0.015584753826260567,
#         -0.005084966775029898,
#         0.0006478678551502526,
#         0.08543527871370316,
#         -0.015885213389992714,
#         0.024089090526103973,
#         -0.007766250055283308,
#         0.01337049063295126,
#         0.021737661212682724,
#         0.014644182287156582,
#         0.0020787292160093784,
#         0.0038667956832796335,
#         -0.0064337728545069695,
#         -0.0065088882111012936,
#         0.003961505834013224,
#         0.013546847738325596,
#         -0.009804155677556992,
#         -0.010437735356390476,
#         0.017139310017228127,
#         -0.00919670332223177,
#         -0.04689795896410942,
#         -0.01972588337957859,
#         0.005800193175673485,
#         0.01000664010643959,
#         -0.009373060427606106,
#         0.005934094078838825,
#         -0.01571538858115673,
#         -0.02138494700193405,
#         -0.01183552946895361,
#         -0.019895708188414574,
#         -0.009960917755961418,
#         -0.00670157466083765,
#         -0.017818612977862358,
#         -0.027772998437285423,
#         0.0003100539615843445,
#         -0.03263261914253235,
#         -0.028896458446979523,
#         -0.011410965584218502,
#         -0.007080416195094585,
#         -0.008034051395952702,
#         -0.029314490035176277,
#         -0.03503630310297012,
#         0.013716673478484154,
#         0.0045003751292824745,
#         0.018001500517129898,
#         0.0031417713034898043,
#         -0.019608311355113983,
#         0.02142413705587387,
#         -0.01416083239018917,
#         -0.0003772085183300078,
#         0.0060647292993962765,
#         -0.0074265990406274796,
#         0.003471624804660678,
#         0.02832166478037834,
#         0.012665062211453915,
#         0.010542243719100952,
#         -0.004036621190607548,
#         -0.0007278817938640714,
#         0.012710784561932087,
#         0.015728453174233437,
#         0.009333869442343712,
#         -0.022064249962568283,
#         0.008968091569840908,
#         -0.016564516350626945,
#         0.001838687458075583,
#         0.0043730060569942,
#         -0.01716543734073639,
#         0.01028097327798605,
#         0.0006507255020551383,
#         -0.018484851345419884,
#         -0.004836760461330414,
#         0.00012849175254814327,
#         -0.0009911929955706,
#         0.006538281217217445,
#         -0.0014353519072756171,
#         0.015062213875353336,
#         -0.01210333127528429,
#         0.003409573109820485,
#         0.01997409015893936,
#         -0.016851913183927536,
#         0.00820387713611126,
#         -0.006162705365568399,
#         0.02691080793738365,
#         0.006910590920597315,
#         -0.02792976051568985,
#         0.008798266761004925,
#         -0.007008566986769438,
#         -0.01109091006219387,
#         -0.013442340306937695,
#         -0.018079882487654686,
#         0.023239964619278908,
#         0.01604197546839714,
#         0.0018435862148180604,
#         0.008262663148343563,
#         -0.014291467145085335,
#         -0.0268062986433506,
#         -0.00894196517765522,
#         0.020183105021715164,
#         -0.017439771443605423,
#         -0.004954332020133734,
#         -0.006786487530916929,
#         -0.008948496542870998,
#         -0.008040583692491055,
#         -0.021724598482251167,
#         -0.024872900918126106,
#         0.022678233683109283,
#         0.002782525261864066,
#         -0.037988655269145966,
#         -0.0009454707033000886,
#         0.010163402184844017,
#         0.00018635897140484303,
#         0.005581379868090153,
#         -0.02612699754536152,
#         -0.025382377207279205,
#         -0.01575457863509655,
#         0.019268659874796867,
#         -0.013148411177098751,
#         0.024703076109290123,
#         0.014774817042052746,
#         0.011522005312144756,
#         -0.01702173799276352,
#         -0.008608845993876457,
#         0.020405184477567673,
#         -0.026492774486541748,
#         -0.006890995427966118,
#         0.006365189794450998,
#         0.06124168261885643,
#         0.02446793206036091,
#         0.015493309125304222,
#         -0.0021228184923529625,
#         0.006603598594665527,
#         0.01679965853691101,
#         -0.008798266761004925,
#         0.0068322098813951015,
#         -0.014918515458703041,
#         0.020065532997250557,
#         -0.00849127396941185,
#         0.0001785004569683224,
#         0.0019578917417675257,
#         -0.012253561988472939,
#         0.027772998437285423,
#         0.008811329491436481,
#         0.0039255814626812935,
#         0.0337560810148716,
#         -0.0014818906784057617,
#         0.008027520030736923,
#         -0.010640219785273075,
#         -0.00875907577574253,
#         0.0036675771698355675,
#         -9.537374717183411e-05,
#         0.0060614631511271,
#         -0.01604197546839714,
#         0.0028315132949501276,
#         -0.014774817042052746,
#         -0.0001234908850165084,
#         0.0023057074286043644,
#         0.027877505868673325,
#         0.027145950123667717,
#         0.017008675262331963,
#         -0.04556548222899437,
#         -0.0033997755963355303,
#         0.02858293429017067,
#         -0.009471036493778229,
#         -0.013285578228533268,
#         -0.00979109201580286,
#         0.0001133870828198269,
#         -0.020104724913835526,
#         0.011672236025333405,
#         0.005568316206336021,
#         0.010685942135751247,
#         -0.009817219339311123,
#         0.011045187711715698,
#         -0.004085609223693609,
#         0.009000750258564949,
#         -0.019961025565862656,
#         -0.006969376467168331,
#         0.01438291184604168,
#         0.00922936201095581,
#         -0.02504272758960724,
#         -0.02367105893790722,
#         0.002656789030879736,
#         -0.0008924002759158611,
#         0.01226662565022707,
#         0.019934898242354393,
#         -0.02197280526161194,
#         0.004278295673429966,
#         -0.009673520922660828,
#         -8.685185457579792e-05,
#         -0.008634972386062145,
#         0.03608138486742973,
#         0.03352093696594238,
#         0.008889710530638695,
#         0.04060135409235954,
#         0.0376490019261837,
#         0.007655210327357054,
#         -0.01990877278149128,
#         -0.0003645532706286758,
#         -0.01831502467393875,
#         -0.008425956591963768,
#         0.01643388159573078,
#         0.025055790320038795,
#         -0.026179250329732895,
#         -0.004474248271435499,
#         -0.003112378530204296,
#         0.009386124089360237,
#         -0.003060124581679702,
#         -0.012162117287516594,
#         0.015467182733118534,
#         0.011802870780229568,
#         0.003912517800927162,
#         0.008132027462124825,
#         -0.005235197022557259,
#         -0.04376272112131119,
#         0.01612035743892193,
#         0.0007315559196285903,
#         -0.007942606694996357,
#         -0.017322199419140816,
#         -0.009177107363939285,
#         -0.01231887936592102,
#         0.0230178851634264,
#         -0.04190770536661148,
#         0.024520186707377434,
#         0.019347041845321655,
#         -0.01774023100733757,
#         -0.020575011149048805,
#         -0.0026518902741372585,
#         -0.03001992031931877,
#         -0.008641504682600498,
#         0.004147660918533802,
#         0.03258036449551582,
#         0.003295267466455698,
#         -0.003791680559515953,
#         0.019752010703086853,
#         -0.004242371302098036,
#         -0.004226041957736015,
#         0.018001500517129898,
#         -0.021907487884163857,
#         0.03660392388701439,
#         0.006051665637642145,
#         -0.007145733572542667,
#         -0.008347575552761555,
#         0.018955135717988014,
#         0.02236470952630043,
#         -0.008830925449728966,
#         0.011789807118475437,
#         0.007080416195094585,
#         -0.01896820031106472,
#         -0.003295267466455698,
#         0.016394691541790962,
#         0.004203180782496929,
#         0.0005747939576394856,
#         0.00026392348809167743,
#         -0.023579614236950874,
#         0.004911875352263451,
#         -0.034121859818696976,
#         -0.015728453174233437,
#         0.009699647314846516,
#         0.05160082131624222,
#         -0.010705537162721157,
#         -0.008791734464466572,
#         -0.012247029691934586,
#         0.022351646795868874,
#         -0.00802098773419857,
#         -0.03493179380893707,
#         0.013109221123158932,
#         0.01028097327798605,
#         -0.017387516796588898,
#         0.002975211711600423,
#         -0.0011569360503926873,
#         0.010685942135751247,
#         0.010013171471655369,
#         0.004379537887871265,
#         0.011678767390549183,
#         -0.016381626948714256,
#         0.031639792025089264,
#         -0.02840004675090313,
#         -0.016525326296687126,
#         -0.028713569045066833,
#         -0.009053004905581474,
#         0.005731610115617514,
#         -0.00921629834920168,
#         -0.018733056262135506,
#         -0.007086948025971651,
#         0.0009634330053813756,
#         0.026610346511006355,
#         0.008837456814944744,
#         -0.010215655900537968,
#         0.0015349610475823283,
#         -0.017792485654354095,
#         0.007877289317548275,
#         0.02467694878578186,
#         -0.01857629418373108,
#         -0.038537319749593735,
#         0.003615323221310973,
#         -0.011554664932191372,
#         -0.0004576306964736432,
#         -0.007864226587116718,
#         -0.021620091050863266,
#         -0.004683264065533876,
#         0.020117787644267082,
#         -0.006257415749132633,
#         -0.0242458526045084,
#         -0.00894196517765522,
#         -0.018341151997447014,
#         -0.019320914521813393,
#         -0.008210408501327038,
#         -0.014892388135194778,
#         -0.0018174592405557632,
#         -0.009960917755961418,
#         0.009346933104097843,
#         -0.009686584584414959,
#         0.02182910591363907,
#         -0.015689261257648468,
#         -0.009457972832024097,
#         -0.012292752042412758,
#         -0.01467030867934227,
#         -0.023030947893857956,
#         -0.023004820570349693,
#         -0.013742800801992416,
#         0.02832166478037834,
#         -0.003471624804660678,
#         -0.023788630962371826,
#         -0.02774687111377716,
#         0.011665704660117626,
#         -0.05039897933602333,
#         0.0017407111590728164,
#         0.0036610455717891455,
#         -0.001512099988758564,
#         -0.015297356992959976,
#         -0.00219466770067811,
#         -0.015558626502752304,
#         0.02236470952630043,
#         0.015728453174233437,
#         0.029105475172400475,
#         -0.022625979036092758,
#         -0.029209982603788376,
#         0.009941322728991508,
#         -0.00047396006993949413,
#         -0.02236470952630043,
#         0.008739480748772621,
#         -0.011241140775382519,
#         -0.03114338032901287,
#         0.0023204039316624403,
#         0.0118159344419837,
#         0.012619339860975742,
#         0.038720209151506424,
#         0.01158079132437706,
#         -0.017857803031802177,
#         -0.00043844367610290647,
#         -0.003706767689436674,
#         -0.009392655454576015,
#         -0.010718600824475288,
#         0.008563123643398285,
#         -0.015441055409610271,
#         -0.0016737607074901462,
#         0.011554664932191372,
#         0.002336733276024461,
#         -0.004640807863324881,
#         -0.0018631814746186137,
#         0.015362674370408058,
#         -0.008615377359092236,
#         0.0037590216379612684,
#         -0.00955594889819622,
#         -0.0013830979587510228,
#         0.009026877582073212,
#         -0.023827821016311646,
#         0.0018631814746186137,
#         0.006544812582433224,
#         0.009366528131067753,
#         0.029863158240914345,
#         -0.008517401292920113,
#         -0.012632403522729874,
#         -0.017687976360321045,
#         0.02215569280087948,
#         -0.007616019807755947,
#         0.010816576890647411,
#         0.0006993053830228746,
#         -0.009275084361433983,
#         -0.007883821614086628,
#         0.00462447851896286,
#         0.018654676154255867,
#         -0.012985117733478546,
#         0.0036055257078260183,
#         0.007047757506370544,
#         -0.010202592238783836,
#         -0.020653391256928444,
#         0.021724598482251167,
#         0.02688468061387539,
#         -0.026936933398246765,
#         -0.006002677604556084,
#         -0.020405184477567673,
#         -0.007315559312701225,
#         -0.009804155677556992,
#         -0.022207947447896004,
#         0.010052362456917763,
#         -0.02471613883972168,
#         0.015297356992959976,
#         0.043997861444950104,
#         -0.007661742158234119,
#         0.008621908724308014,
#         -0.009340401738882065,
#         0.00022391653328668326,
#         0.005927562713623047,
#         0.00955594889819622,
#         0.23472493886947632,
#         -0.006035336293280125,
#         -0.018706930801272392,
#         0.04843945428729057,
#         0.0024314436595886946,
#         0.038354430347681046,
#         0.001688457210548222,
#         -0.01434372179210186,
#         -0.006378252990543842,
#         0.016682088375091553,
#         0.011103973723948002,
#         0.0008491274202242494,
#         -0.0002557588159106672,
#         0.00577080063521862,
#         -0.019386231899261475,
#         -0.01655145362019539,
#         -0.013520721346139908,
#         -0.0051143597811460495,
#         -0.004513438791036606,
#         -0.03177042677998543,
#         0.007916480302810669,
#         -0.0066264597699046135,
#         0.005293983034789562,
#         0.0059471577405929565,
#         0.005444212816655636,
#         -0.020143914967775345,
#         -0.0023661262821406126,
#         0.0008662732434459031,
#         0.009634329937398434,
#         0.00030964575125835836,
#         -0.03427862003445625,
#         -0.0024085824843496084,
#         0.02334447205066681,
#         0.000609085604082793,
#         -0.027041442692279816,
#         -0.021515581756830215,
#         0.030542459338903427,
#         0.0027645628433674574,
#         0.035898495465517044,
#         0.011319521814584732,
#         -0.0003274039481766522,
#         -0.014696436002850533,
#         0.013677483424544334,
#         -0.004676732700318098,
#         -0.014304530806839466,
#         0.022965630516409874,
#         -0.018667738884687424,
#         -0.015205912292003632,
#         -0.02124124951660633,
#         0.016969485208392143,
#         -0.018419532105326653,
#         -0.020444374531507492,
#         0.0009299577795900404,
#         0.011913910508155823,
#         0.021907487884163857,
#         -0.008732948452234268,
#         0.026754045858979225,
#         -0.024559376761317253,
#         0.020431311801075935,
#         0.02023535966873169,
#         2.3779650291544385e-05,
#         0.009653925895690918,
#         -0.05518021807074547,
#         0.034121859818696976,
#         -0.023253027349710464,
#         -0.00997398141771555,
#         -0.030699221417307854,
#         0.02973252348601818,
#         -0.002921324921771884,
#         -0.007433130871504545,
#         -0.007805440574884415,
#         -0.0021309831645339727,
#         0.02709369547665119,
#         -0.002609433839097619,
#         -0.03331192210316658,
#         -0.027955887839198112,
#         0.0354020819067955,
#         0.0059144990518689156,
#         0.034121859818696976,
#         0.034304745495319366,
#         -0.00998704507946968,
#         0.002715574810281396,
#         0.009960917755961418,
#         -0.007903416641056538,
#         -0.030908238142728806,
#         -0.014696436002850533,
#         -0.005235197022557259,
#         -0.017113182693719864,
#         -0.023044010624289513,
#         0.0016868242528289557,
#         -0.008602313697338104,
#         -0.00666565028950572,
#         0.00124838063493371,
#         -0.029758648946881294,
#         -0.0014745424268767238,
#         0.028609061613678932,
#         0.0065088882111012936,
#         0.00845208391547203,
#         -0.0008156521944329143,
#         0.0038504661060869694,
#         -0.009327338077127934,
#         0.024624694138765335,
#         0.01849791407585144,
#         0.025826536118984222,
#         -0.0007152265752665699,
#         0.01759653352200985,
#         -0.01382118184119463,
#         -0.003389977850019932,
#         0.014317594468593597,
#         -0.01896820031106472,
#         -0.013200664892792702,
#         -0.014853198081254959,
#         0.006580737419426441,
#         -0.0005094764637760818,
#         0.01158079132437706,
#         0.015114467591047287,
#         0.013808118179440498,
#         -0.004052950534969568,
#         0.005068637430667877,
#         0.003442231798544526,
#         0.01983039081096649,
#         -0.005369097925722599,
#         -0.01597665809094906,
#         0.01313534751534462,
#         0.012665062211453915,
#         -0.008073242381215096,
#         -0.017478961497545242,
#         -0.0068648685701191425,
#         0.012247029691934586,
#         -0.03352093696594238,
#         0.0025522811338305473,
#         -0.007785845082253218,
#         0.035428207367658615,
#         -0.0004143578407820314,
#         0.0014957706443965435,
#         -0.011469751596450806,
#         -0.004768176935613155,
#         0.02103223279118538,
#         -0.020836280658841133,
#         0.0069497814401984215,
#         0.022273264825344086,
#         -0.018628548830747604,
#         -0.013742800801992416,
#         0.00955594889819622,
#         -0.01626405492424965,
#         -0.03414798527956009,
#         0.022769678384065628,
#         -0.020823216065764427,
#         -0.011822465807199478,
#         0.005725078284740448,
#         -0.02128043957054615,
#         -0.009111789986491203,
#         0.006365189794450998,
#         0.007315559312701225,
#         0.04431138560175896,
#         -0.004755113273859024,
#         -0.021411074325442314,
#         -0.050895389169454575,
#         -0.0006719537195749581,
#         0.0028935649897903204,
#         -0.03924274817109108,
#         -0.0008899508393369615,
#         0.041176147758960724,
#         -0.023030947893857956,
#         -0.011005997657775879,
#         0.004431792069226503,
#         -0.16669024527072906,
#         0.017949247732758522,
#         0.0049086096696555614,
#         -0.01252136379480362,
#         0.013102688826620579,
#         0.0013667684979736805,
#         0.046845704317092896,
#         -0.0163685642182827,
#         -0.011887784115970135,
#         0.003350787330418825,
#         0.022456154227256775,
#         -0.030620841309428215,
#         -0.023827821016311646,
#         0.011201949790120125,
#         -0.008785203099250793,
#         0.013507657684385777,
#         -0.019712818786501884,
#         -0.037884145975112915,
#         0.03973916172981262,
#         0.012638934887945652,
#         0.012763038277626038,
#         -0.020261486992239952,
#         0.015989722684025764,
#         0.016055040061473846,
#         0.016669023782014847,
#         -0.001413307269103825,
#         -0.0163685642182827,
#         0.013899562880396843,
#         0.008210408501327038,
#         -0.009588607586920261,
#         -0.007674805354326963,
#         0.008406361564993858,
#         0.013729737140238285,
#         0.006175769027322531,
#         0.0011830631410703063,
#         -3.0847208108752966e-05,
#         0.013207197189331055,
#         -0.0006523584597744048,
#         -0.02384088560938835,
#         0.008517401292920113,
#         -0.002103223232552409,
#         0.01031363196671009,
#         0.0075768292881548405,
#         -0.001992183504626155,
#         -0.012312347069382668,
#         0.013279045931994915,
#         0.023279154673218727,
#         0.004696327727288008,
#         0.023174647241830826,
#         -0.00237102503888309,
#         0.0019023719942197204,
#         -0.025565266609191895,
#         -0.012599744834005833,
#         0.0004764094774145633,
#         0.011711426079273224,
#         0.003112378530204296,
#         -0.019124962389469147,
#         0.008576186373829842,
#         0.010705537162721157,
#         0.01052918005734682,
#         -0.00073400535620749,
#         -0.029601888731122017,
#         0.0025016600266098976,
#         0.005101296119391918,
#         -0.006437039002776146,
#         -0.0164730716496706,
#         -0.03224071487784386,
#         0.0151928486302495,
#         -0.0035793986171483994,
#         0.00901381392031908,
#         0.0038112758193165064,
#         0.0016704949084669352,
#         -0.004134597256779671,
#         -0.02561752125620842,
#         -0.0027972215320914984,
#         0.0048236967995762825,
#         -0.017008675262331963,
#         0.037805765867233276,
#         -0.02226020209491253,
#         0.007367813028395176,
#         0.007844630628824234,
#         0.009601671248674393,
#         -0.0037459582090377808,
#         0.009275084361433983,
#         0.008360639214515686,
#         0.006760360673069954,
#         0.02461163140833378,
#         0.007093479856848717,
#         -0.008380234241485596,
#         -0.018602421507239342,
#         0.0261923149228096,
#         -0.039765290915966034,
#         -0.009588607586920261,
#         -0.02850455418229103,
#         0.017335262149572372,
#         0.019791200757026672,
#         -0.01763572357594967,
#         -0.0016435513971373439,
#         0.008556591346859932,
#         -0.0011553032090887427,
#         -0.02041824907064438,
#         -0.0069955033250153065,
#         -0.0241413451731205,
#         0.03464439883828163,
#         0.0403139553964138,
#         -0.0008613744284957647,
#         0.016342436894774437,
#         0.013416212983429432,
#         0.04324018210172653,
#         0.0038308710791170597,
#         -0.03263261914253235,
#         -0.0199479628354311,
#         0.011548132635653019,
#         0.02655809186398983,
#         0.034487634897232056,
#         0.028452299535274506,
#         -0.0018337885849177837,
#         -0.0029164261650294065,
#         -0.00224528880789876,
#         0.018223579972982407,
#         0.05904701352119446,
#         -0.021985867992043495,
#         -0.026427457109093666,
#         0.02753785438835621,
#         -0.0014818906784057617,
#         -0.01538880169391632,
#         -0.05011158064007759,
#         -0.04000043123960495,
#         0.02600942552089691,
#         0.047786276787519455,
#         0.00796873401850462,
#         0.017426706850528717,
#         0.017283009365200996,
#         0.011280330829322338,
#         -0.03085598349571228,
#         -0.0038178074173629284,
#         -0.014683372341096401,
#         -0.011574259959161282,
#         -0.011685299687087536,
#         -0.006570939905941486,
#         -0.013083093799650669,
#         0.001471276511438191,
#         0.0011259103193879128,
#         -0.019164152443408966,
#         -0.0021342490799725056,
#         0.03323354199528694,
#         -0.006525217555463314,
#         -0.0028380451258271933,
#         0.010836171917617321,
#         -0.03506242856383324,
#         -0.017478961497545242,
#         -0.0024379754904657602,
#         -0.01796231046319008,
#         0.034957922995090485,
#         -0.002829880453646183,
#         0.002733536995947361,
#         -0.0059144990518689156,
#         -0.024154409766197205,
#         -0.0014410672010853887,
#         0.0006123515195213258,
#         -0.001820725155994296,
#         -0.01101906131953001,
#         -0.03639490529894829,
#         -0.0030176681466400623,
#         0.017544278874993324,
#         -0.006054931785911322,
#         0.01183552946895361,
#         0.01723075471818447,
#         0.010124211199581623,
#         -0.01208373624831438,
#         0.00615943968296051,
#         -0.016499198973178864,
#         0.005800193175673485,
#         0.029183855280280113,
#         -0.01726994477212429,
#         -0.036264270544052124,
#         -0.0012271524174138904,
#         -0.008661099709570408,
#         -0.05173145607113838,
#         -0.003945176489651203,
#         0.03148303180932999,
#         -0.004660403355956078,
#         0.030516332015395164,
#         0.002044437453150749,
#         -0.018654676154255867,
#         -0.00796873401850462,
#         -0.017034802585840225,
#         0.010659814812242985,
#         -0.0011814301833510399,
#         0.0030699220951646566,
#         -0.010013171471655369,
#         0.01235806941986084,
#         -0.018811438232660294,
#         -0.008458615280687809,
#         0.007243710104376078,
#         0.013951816596090794,
#         0.0018664473900571465,
#         0.0006907325005158782,
#         -0.02727658487856388,
#         0.04057522490620613,
#         -0.05000707134604454,
#         0.0052678557112813,
#         -0.026832425966858864,
#         -0.022142630070447922,
#         0.013559911400079727,
#         -0.009301210753619671,
#         -0.017505088821053505,
#         -0.010699005797505379,
#         0.0026078009977936745,
#         -0.016460008919239044,
#         0.011365244165062904,
#         0.007583361119031906,
#         -0.012116394937038422,
#         -0.009170575998723507,
#         -0.003247912274673581,
#         -0.01864161342382431,
#         0.008118964731693268,
#         0.004059482365846634,
#         0.02485983818769455,
#         -0.02887033112347126,
#         -0.030829856172204018,
#         0.009131385944783688,
#         0.004941268358379602,
#         0.0027139417361468077,
#         0.029000967741012573,
#         0.018654676154255867,
#         -0.005476871971040964,
#         -0.04180319607257843,
#         -0.06139844283461571,
#         0.009595139883458614,
#         0.012906736694276333,
#         -0.03312903270125389,
#         -0.015989722684025764,
#         0.021084487438201904,
#         0.003092783270403743,
#         -0.011874720454216003,
#         0.0017782687209546566,
#         0.012906736694276333,
#         -0.0012753240298479795,
#         0.0036316525656729937,
#         -0.0039059859700500965,
#         -0.007785845082253218,
#         -0.024951282888650894,
#         -0.024115217849612236,
#         0.029209982603788376,
#         0.004523236304521561,
#         0.016460008919239044,
#         0.018079882487654686,
#         0.007537638768553734,
#         -0.013109221123158932,
#         0.01203148253262043,
#         0.010601028800010681,
#         -0.018445659428834915,
#         -0.0039255814626812935,
#         -0.03406960517168045,
#         0.004212978295981884,
#         -0.022495344281196594,
#         -0.00681914621964097,
#         0.012651998549699783,
#         -0.02698918804526329,
#         0.004980458877980709,
#         -0.010607561096549034,
#         -0.01203148253262043,
#         -0.0007168594747781754,
#         -0.014369848184287548,
#         0.013011245056986809,
#         0.03265874832868576,
#         0.008523932658135891,
#         -0.011926974169909954,
#         -0.04663668945431709,
#         0.005182942841202021,
#         -0.0018778779776766896,
#         -0.03067309409379959,
#         0.023618806153535843,
#         -0.013083093799650669,
#         0.009666988626122475,
#         0.012795696966350079,
#         0.004252168815582991,
#         0.0029147930908948183,
#         0.01843259669840336,
#         -0.011587323620915413,
#         -0.0026078009977936745,
#         0.019778136163949966,
#         -0.02725045755505562,
#         0.012077204883098602,
#         0.003883125027641654,
#         0.019242532551288605,
#         -0.019882645457983017,
#         0.03926887735724449,
#         -0.003687172429636121,
#         0.0052678557112813,
#         0.01416083239018917,
#         0.005917764734476805,
#         0.006139844190329313,
#         0.00462447851896286,
#         0.0006866501644253731,
#         0.012998181395232677,
#         -0.020966915413737297,
#         -0.013004712760448456,
#         0.0033997755963355303,
#         0.014853198081254959,
#         -0.0003251586458645761,
#         0.013285578228533268,
#         0.016721278429031372,
#         -0.00115203729365021,
#         -0.01076432317495346,
#         -0.010444266721606255,
#         0.02981090359389782,
#         -0.014095515012741089,
#         0.011169291101396084,
#         -0.028530681505799294,
#         -0.0007425782387144864,
#         0.0060973879881203175,
#         0.006090856157243252,
#         -0.0034030412789434195,
#         0.020039407536387444,
#         0.010411608032882214,
#         -0.006257415749132633,
#         -0.057792916893959045,
#         0.007811971940100193,
#         0.012795696966350079,
#         -0.0011201950255781412,
#         0.0034552954602986574,
#         0.009921726770699024,
#         0.03305065259337425,
#         -0.004771443083882332,
#         0.028086522594094276,
#         0.01933397725224495,
#         0.01878531090915203,
#         -0.000990376458503306,
#         0.01362522877752781,
#         -0.017100119963288307,
#         -0.010124211199581623,
#         -0.006146376021206379,
#         0.004657137207686901,
#         -0.03511468321084976,
#         -0.006858336739242077,
#         0.024977410212159157,
#         0.01033322699368,
#         -0.018654676154255867,
#         -0.023971520364284515,
#         0.0034846882335841656,
#         -0.019124962389469147,
#         -0.006459900178015232,
#         -0.016864975914359093,
#         0.02438955195248127,
#         -0.01947767660021782,
#         0.015885213389992714,
#         0.010156869888305664,
#         0.019921835511922836,
#         0.033834461122751236,
#         -0.025160297751426697,
#         0.03085598349571228,
#         0.01363829243928194,
#         0.006812614388763905,
#         -0.008667631074786186,
#         0.018994327634572983,
#         0.019373169168829918,
#         0.01101906131953001,
#         0.02355348877608776,
#         -0.02944512665271759,
#         -0.0278252512216568,
#         -0.017361389473080635,
#         0.02074483595788479,
#         -0.007622551638633013,
#         0.002678017131984234,
#         -0.034853413701057434,
#         0.07399165630340576,
#         0.003935378976166248,
#         -0.018341151997447014,
#         -0.0027188407257199287,
#         -0.0002929081383626908,
#         0.003027465892955661,
#         0.017008675262331963,
#         0.017648786306381226,
#         -0.015310420654714108,
#         -0.014239213429391384,
#         0.03508855774998665,
#         -0.008909306488931179,
#         4.115512274438515e-05,
#         -0.047028593719005585,
#         -0.026832425966858864,
#         0.02478145621716976,
#         -0.020575011149048805,
#         0.01962137408554554,
#         -0.013781990855932236,
#         0.017073992639780045,
#         0.022377772256731987,
#         0.01304390374571085,
#         -0.008615377359092236,
#         0.011619982309639454,
#         -0.003331192070618272,
#         -0.009392655454576015,
#         0.021724598482251167,
#         -0.010032766498625278,
#         0.0009585341904312372,
#         -0.016198737546801567,
#         0.004862887319177389,
#         0.0054376814514398575,
#         -0.03767513111233711,
#         -0.013200664892792702,
#         -0.0027139417361468077,
#         -0.010679409839212894,
#         -0.029654141515493393,
#         -0.010222187265753746,
#         0.013272514566779137,
#         0.0010050729615613818,
#         0.013246387243270874,
#         0.04120227321982384,
#         -0.020287612453103065,
#         0.01007848884910345,
#         0.009895600378513336,
#         -0.017400579527020454,
#         -0.014030197635293007,
#         0.0069824401289224625,
#         0.011822465807199478
#       ]
#     }
#   ],
#   "model": "text-embedding-ada-002",
#   "usage": {
#     "prompt_tokens": 9,
#     "total_tokens": 9
#   }
# }

# %% [markdown]
# 유사도 검색

# %%
import openai
import numpy as np

# 입력 텍스트의 임베딩 생성
in_text = "오늘은 비가 오지 않아서 다행이다."
response = openai.Embedding.create(
    input=in_text,
    model="text-embedding-ada-002"
)
in_embeds = [record["embedding"] for record in response["data"]]
in_embeds = np.array(in_embeds).astype("float32")

# 대상 텍스트의 임베딩 생성
target_texts = [
    "좋아하는 음식은 무엇인가요?",
    "어디에 살고 계신가요?",
    "아침 전철은 혼잡하네요.",
    "오늘은 날씨가 좋네요!",
    "요즘 경기가 좋지 않네요."]
response = openai.Embedding.create(
    input=target_texts,
    model="text-embedding-ada-002"
)
target_embeds = [record["embedding"] for record in response["data"]]
target_embeds = np.array(target_embeds).astype("float32")

# %%
import faiss

# Faiss의 인덱스 생성
index = faiss.IndexFlatL2(1536)

# %%
# 대상 텍스트를 인덱스에 추가
index.add(target_embeds)

# %%
# 유사도 검색 수행
D, I = index.search(in_embeds, 1)

# 확인
print(D)
print(I)
print(target_texts[I[0][0]])
# Out:
# [[0.3348269]]
# [[3]]
# 오늘은 날씨가 좋네요!

# %% [markdown]
# 모더레이션

# %%
import openai

# 모더레이션 이용
response = openai.Moderation.create(
    input="I'll kill you!"
)
print(response)
# Out:
# {
#   "id": "modr-9zh34NGbEkHfSpbDwOjScJJS9PEio",
#   "model": "text-moderation-007",
#   "results": [
#     {
#       "flagged": true,
#       "categories": {
#         "sexual": false,
#         "hate": false,
#         "harassment": false,
#         "self-harm": false,
#         "sexual/minors": false,
#         "hate/threatening": false,
#         "violence/graphic": false,
#         "self-harm/intent": false,
#         "self-harm/instructions": false,
#         "harassment/threatening": true,
#         "violence": true
#       },
#       "category_scores": {
#         "sexual": 6.244780524866655e-05,
#         "hate": 0.0015544898342341185,
#         "harassment": 0.4280489981174469,
#         "self-harm": 1.214574422192527e-05,
#         "sexual/minors": 5.129344913257228e-07,
#         "hate/threatening": 0.00034368637716397643,
#         "violence/graphic": 0.00013634905917569995,
#         "self-harm/intent": 2.1098701381561114e-06,
#         "self-harm/instructions": 1.190132579154124e-07,
#         "harassment/threatening": 0.4650719165802002,
#         "violence": 0.9984785914421082
#       }
#     }
#   ]
# }

# %%
print(response)
# Out:
# {
#   "id": "modr-9zh34NGbEkHfSpbDwOjScJJS9PEio",
#   "model": "text-moderation-007",
#   "results": [
#     {
#       "flagged": true,
#       "categories": {
#         "sexual": false,
#         "hate": false,
#         "harassment": false,
#         "self-harm": false,
#         "sexual/minors": false,
#         "hate/threatening": false,
#         "violence/graphic": false,
#         "self-harm/intent": false,
#         "self-harm/instructions": false,
#         "harassment/threatening": true,
#         "violence": true
#       },
#       "category_scores": {
#         "sexual": 6.244780524866655e-05,
#         "hate": 0.0015544898342341185,
#         "harassment": 0.4280489981174469,
#         "self-harm": 1.214574422192527e-05,
#         "sexual/minors": 5.129344913257228e-07,
#         "hate/threatening": 0.00034368637716397643,
#         "violence/graphic": 0.00013634905917569995,
#         "self-harm/intent": 2.1098701381561114e-06,
#         "self-harm/instructions": 1.190132579154124e-07,
#         "harassment/threatening": 0.4650719165802002,
#         "violence": 0.9984785914421082
#       }
#     }
#   ]
# }

# %% [markdown]
# ### speach_to_text

# %% [markdown]
# 음성 텍스트 변환

# %%
import openai

# 음성 텍스트 변환(현재 폴더에 오디오 파일을 업로드해두세요)
audio_file= open("data/audio.mp3", "rb")
transcript = openai.Audio.transcribe("whisper-1", audio_file)
print(transcript["text"])
# Out:
# Whisper는 범위온 음성인식 모델입니다. 다양한 오디오의 대규모 데이터 시트를 학습하고 다국어 음성인식, 음성번역, 언어식별을 수행할 수 있는 멀티태스킹 모델이기도 합니다.

# %% [markdown]
# 음성을 영어로 번역해서 텍스트로 저장하기

# %%
# 오디오 파일 번역 및 변환
audio_file_path = "data/audio.mp3"  # 오디오 파일 경로
output_file_path = "transcript.txt"  # 저장할 파일 경로

# 오디오 파일 열기
with open(audio_file_path, "rb") as audio_file:
    # Whisper 모델을 사용하여 음성 번역 및 변환
    transcript = openai.Audio.translate("whisper-1", audio_file)

# 번역된 텍스트 저장
with open(output_file_path, "w") as output_file:
    output_file.write(transcript["text"])

print("번역된 텍스트가 저장되었습니다:", output_file_path)
# Out:
# 번역된 텍스트가 저장되었습니다: transcript.txt

# %%
음성을 중국어로 번역해서 텍스트로 저장하기

# %%
import openai

# 오디오 파일 경로와 출력 파일 경로 설정
audio_file_path = "datasets/gpt/audio.mp3"  # 오디오 파일 경로
output_file_path = "transcript-chi.txt"  # 저장할 파일 경로

# 오디오 파일 열기
with open(audio_file_path, "rb") as audio_file:
    # Whisper 모델을 사용하여 음성 번역 및 변환
    transcript = openai.Audio.translate("whisper-1", audio_file)

# 번역된 텍스트를 영어에서 중국어로 번역
english_text = transcript["text"]
prompt = f"Translate the following English text to Chinese: {english_text}"

# 번역 요청
translation_response = openai.Completion.create(
    model="gpt-3.5-turbo-instruct",
    prompt=prompt,
    temperature=0.7,
    max_tokens=500
)

# 번역된 텍스트 저장
chinese_text = translation_response["choices"][0]["text"].strip()
with open(output_file_path, "w", encoding="utf-8") as output_file:  # UTF-8 인코딩 사용
    output_file.write(chinese_text)

print("번역된 텍스트가 저장되었습니다:", output_file_path)

# %% [markdown]
# ### 토크나이저

# %% [markdown]
# 토크나이저 사용

# %%
import tiktoken

# 인코딩 획득
enc = tiktoken.get_encoding("cl100k_base")

# %%
# 인코딩 실행
tokens = enc.encode("Hello World!")
print(len(tokens))
print(tokens)
# Out:
# 3
# [9906, 4435, 0]

# %%
# 디코딩 실행
print(enc.decode(tokens))
# Out:
# Hello World!

# %%
# 분할된 상태에서 디코딩 실행
print(enc.decode_tokens_bytes(tokens))
# Out:
# [b'Hello', b' World', b'!']

# %% [markdown]
# 한국어와 영어의 토큰 수 비교

# %%
# 인코딩 실행
tokens = enc.encode("안녕, 세상아!")
print(len(tokens))
print(tokens)
# Out:
# 10
# [31495, 230, 75265, 243, 11, 28867, 116, 57002, 54059, 0]

# %%
# 디코딩 실행
print(enc.decode(tokens))
# Out:
# 안녕, 세상아!

# %%
# 분할된 상태로 디코딩
def data2str(data):
    try:
        return data.decode('utf-8')
    except UnicodeError:
        return data
print([data2str(data) for data in enc.decode_tokens_bytes(tokens)])
# Out:
# [b'\xec\x95', b'\x88', b'\xeb\x85', b'\x95', ',', b' \xec\x84', b'\xb8', '상', '아', '!']

# %%
import tiktoken
# 인코딩 확인
print(tiktoken.encoding_for_model("gpt-4"))
# Out:
# <Encoding 'cl100k_base'>

# %%
DATA_IN_PATH = './data_in/'

# %%
data = pd.read_csv(DATA_IN_PATH + 'ChatBotData.csv', encoding='utf-8')

# %%
data
# Out:
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.      0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.      0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.      0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.      0
# 4                      PPL 심하네                눈살이 찌푸려지죠.      0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2
#
# [11823 rows x 3 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
print(data.head())
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %%
print(data.tail())
# Out:
#                              Q                         A  label
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11823 entries, 0 to 11822
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q       11823 non-null  object
#  1   A       11823 non-null  object
#  2   label   11823 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 277.2+ KB
# None

# %%
print(data.shape)
# Out:
# (11823, 3)

# %%
print(dir(data))
# Out:
# ['A', 'Q', 'T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_accessors', '_accum_func', '_agg_examples_doc', '_agg_see_also_doc', '_align_for_op', '_align_frame', '_align_series', '_append', '_arith_method', '_arith_method_with_reindex', '_as_manager', '_attrs', '_box_col_values', '_can_fast_transpose', '_check_inplace_and_allows_duplicate_labels', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_combine_frame', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_result', '_constructor', '_constructor_from_mgr', '_constructor_sliced', '_constructor_sliced_from_mgr', '_create_data_for_split_and_tight_to_dict', '_data', '_deprecate_downcast', '_dir_additions', '_dir_deletions', '_dispatch_frame_op', '_drop_axis', '_drop_labels_or_levels', '_ensure_valid_index', '_find_valid_index', '_flags', '_flex_arith_method', '_flex_cmp_method', '_from_arrays', '_from_mgr', '_get_agg_axis', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cleaned_column_resolvers', '_get_column_array', '_get_index_resolvers', '_get_item_cache', '_get_label_or_level_values', '_get_numeric_data', '_get_value', '_get_values_for_csv', '_getitem_bool_array', '_getitem_multilevel', '_getitem_nocopy', '_getitem_slice', '_gotitem', '_hidden_attrs', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_info_repr', '_init_mgr', '_inplace_method', '_internal_names', '_internal_names_set', '_is_copy', '_is_homogeneous_type', '_is_label_or_level_reference', '_is_label_reference', '_is_level_reference', '_is_mixed_type', '_is_view', '_is_view_after_cow_rules', '_iset_item', '_iset_item_mgr', '_iset_not_inplace', '_item_cache', '_iter_column_arrays', '_ixs', '_logical_func', '_logical_method', '_maybe_align_series_as_frame', '_maybe_cache_changed', '_maybe_update_cacher', '_metadata', '_mgr', '_min_count_stat_function', '_needs_reindex_multi', '_pad_or_backfill', '_protect_consolidate', '_reduce', '_reduce_axis1', '_reindex_axes', '_reindex_multi', '_reindex_with_indexers', '_rename', '_replace_columnwise', '_repr_data_resource_', '_repr_fits_horizontal_', '_repr_fits_vertical_', '_repr_html_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_sanitize_column', '_series', '_set_axis', '_set_axis_name', '_set_axis_nocheck', '_set_is_copy', '_set_item', '_set_item_frame_value', '_set_item_mgr', '_set_value', '_setitem_array', '_setitem_frame', '_setitem_slice', '_shift_with_freq', '_should_reindex_frame_op', '_slice', '_stat_function', '_stat_function_ddof', '_take_with_is_copy', '_to_dict_of_blocks', '_to_latex_ ...

# %%
sentences = list(data['Q']) + list(data['A'])

# %%
tokenized_sentences = [s.split() for s in sentences]
sent_len_by_token = [len(t) for t in tokenized_sentences]
sent_len_by_eumjeol = [len(s.replace(' ', '')) for s in sentences]

okt = Okt()

morph_tokenized_sentences = [okt.morphs(s.replace(' ', '')) for s in sentences]
sent_len_by_morph = [len(t) for t in morph_tokenized_sentences]

# %%
plt.figure(figsize=(12, 5))
plt.hist(sent_len_by_token, bins=50, range=[0,50], alpha=0.5, color= 'r', label='eojeol')
plt.hist(sent_len_by_morph, bins=50, range=[0,50], alpha=0.5, color='g', label='morph')
plt.hist(sent_len_by_eumjeol, bins=50, range=[0,50], alpha=0.5, color='b', label='eumjeol')
plt.title('Sentence Length Histogram')
plt.xlabel('Sentence Length')
plt.ylabel('Number of Sentences')
# Out:
# Text(0, 0.5, 'Number of Sentences')

# %%
plt.figure(figsize=(12, 5))
plt.hist(sent_len_by_token, bins=50, range=[0,50], alpha=0.5, color= 'r', label='eojeol')
plt.hist(sent_len_by_morph, bins=50, range=[0,50], alpha=0.5, color='g', label='morph')
plt.hist(sent_len_by_eumjeol, bins=50, range=[0,50], alpha=0.5, color='b', label='eumjeol')
plt.yscale('log')
plt.title('Sentence Length Histogram by Eojeol Token')
plt.xlabel('Sentence Length')
plt.ylabel('Number of Sentences')
# Out:
# Text(0, 0.5, 'Number of Sentences')

# %%
print('어절 최대길이: {}'.format(np.max(sent_len_by_token)))
print('어절 최소길이: {}'.format(np.min(sent_len_by_token)))
print('어절 평균길이: {:.2f}'.format(np.mean(sent_len_by_token)))
print('어절 길이 표준편차: {:.2f}'.format(np.std(sent_len_by_token)))
print('어절 중간길이: {}'.format(np.median(sent_len_by_token)))
print('제 1 사분위 길이: {}'.format(np.percentile(sent_len_by_token, 25)))
print('제 3 사분위 길이: {}'.format(np.percentile(sent_len_by_token, 75)))
# Out:
# 어절 최대길이: 21
# 어절 최소길이: 1
# 어절 평균길이: 3.64
# 어절 길이 표준편차: 1.74
# 어절 중간길이: 3.0
# 제 1 사분위 길이: 2.0
# 제 3 사분위 길이: 5.0

# %%
print('형태소 최대길이: {}'.format(np.max(sent_len_by_morph)))
print('형태소 최소길이: {}'.format(np.min(sent_len_by_morph)))
print('형태소 평균길이: {:.2f}'.format(np.mean(sent_len_by_morph)))
print('형태소 길이 표준편차: {:.2f}'.format(np.std(sent_len_by_morph)))
print('형태소 중간길이: {}'.format(np.median(sent_len_by_morph)))
print('형태소 1/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_morph, 25)))
print('형태소 3/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_morph, 75)))
# Out:
# 형태소 최대길이: 31
# 형태소 최소길이: 1
# 형태소 평균길이: 5.41
# 형태소 길이 표준편차: 2.56
# 형태소 중간길이: 5.0
# 형태소 1/4 퍼센타일 길이: 4.0
# 형태소 3/4 퍼센타일 길이: 7.0

# %%
print('음절 최대길이: {}'.format(np.max(sent_len_by_eumjeol)))
print('음절 최소길이: {}'.format(np.min(sent_len_by_eumjeol)))
print('음절 평균길이: {:.2f}'.format(np.mean(sent_len_by_eumjeol)))
print('음절 길이 표준편차: {:.2f}'.format(np.std(sent_len_by_eumjeol)))
print('음절 중간길이: {}'.format(np.median(sent_len_by_eumjeol)))
print('음절 1/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_eumjeol, 25)))
print('음절 3/4 퍼센타일 길이: {}'.format(np.percentile(sent_len_by_eumjeol, 75)))
# Out:
# 음절 최대길이: 57
# 음절 최소길이: 1
# 음절 평균길이: 11.31
# 음절 길이 표준편차: 4.98
# 음절 중간길이: 10.0
# 음절 1/4 퍼센타일 길이: 8.0
# 음절 3/4 퍼센타일 길이: 14.0

# %%
plt.figure(figsize=(12, 5))
plt.boxplot([sent_len_by_token, sent_len_by_morph, sent_len_by_eumjeol],
            labels=['Eojeol', 'Morph', 'Eumjeol'],
            showmeans=True)
# Out:
# C:\Users\10300\AppData\Local\Temp\ipykernel_8860\3431909120.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([sent_len_by_token, sent_len_by_morph, sent_len_by_eumjeol],
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d60fda1240>,
#   <matplotlib.lines.Line2D at 0x1d60fda14e0>,
#   <matplotlib.lines.Line2D at 0x1d60fda2770>,
#   <matplotlib.lines.Line2D at 0x1d60fda2a10>,
#   <matplotlib.lines.Line2D at 0x1d60fda3c70>,
#   <matplotlib.lines.Line2D at 0x1d60fda3f10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1d60fda1780>,
#   <matplotlib.lines.Line2D at 0x1d60fda1a20>,
#   <matplotlib.lines.Line2D at 0x1d60fda2cb0>,
#   <matplotlib.lines.Line2D at 0x1d60fda2f50>,
#   <matplotlib.lines.Line2D at 0x1d60fddc1f0>,
#   <matplotlib.lines.Line2D at 0x1d60fddc490>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1d60fda0f40>,
#   <matplotlib.lines.Line2D at 0x1d60fda24d0>,
#   <matplotlib.lines.Line2D at 0x1d60fda39d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d60fda1cc0>,
#   <matplotlib.lines.Line2D at 0x1d60fda31f0>,
#   <matplotlib.lines.Line2D at 0x1d60fddc730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d60fda2200>,
#   <matplotlib.lines.Line2D at 0x1d60fda3730>,
#   <matplotlib.lines.Line2D at 0x1d60fddcc70>],
#  'means': [<matplotlib.lines.Line2D at 0x1d60fda1f60>,
#   <matplotlib.lines.Line2D at 0x1d60fda3490>,
#   <matplotlib.lines.Line2D at 0x1d60fddc9d0>]}

# %%
query_sentences = list(data['Q'])
answer_sentences = list(data['A'])

query_morph_tokenized_sentences = [okt.morphs(s.replace(' ', '')) for s in query_sentences]
query_sent_len_by_morph = [len(t) for t in query_morph_tokenized_sentences]

answer_morph_tokenized_sentences = [okt.morphs(s.replace(' ', '')) for s in answer_sentences]
answer_sent_len_by_morph = [len(t) for t in answer_morph_tokenized_sentences]

# %%
plt.figure(figsize=(12, 5))
plt.hist(query_sent_len_by_morph, bins=50, range=[0,50], color='g', label='Query')
plt.hist(answer_sent_len_by_morph, bins=50, range=[0,50], color='r', alpha=0.5, label='Answer')
plt.legend()
plt.title('Query Length Histogram by Morph Token')
plt.xlabel('Query Length')
plt.ylabel('Number of Queries')
# Out:
# Text(0, 0.5, 'Number of Queries')

# %%
print('형태소 최대길이: {}'.format(np.max(query_sent_len_by_morph)))
print('형태소 최소길이: {}'.format(np.min(query_sent_len_by_morph)))
print('형태소 평균길이: {:.2f}'.format(np.mean(query_sent_len_by_morph)))
print('형태소 길이 표준편차: {:.2f}'.format(np.std(query_sent_len_by_morph)))
print('형태소 중간길이: {}'.format(np.median(query_sent_len_by_morph)))
print('형태소 1/4 퍼센타일 길이: {}'.format(np.percentile(query_sent_len_by_morph, 25)))
print('형태소 3/4 퍼센타일 길이: {}'.format(np.percentile(query_sent_len_by_morph, 75)))
# Out:
# 형태소 최대길이: 20
# 형태소 최소길이: 1
# 형태소 평균길이: 4.95
# 형태소 길이 표준편차: 2.48
# 형태소 중간길이: 4.0
# 형태소 1/4 퍼센타일 길이: 3.0
# 형태소 3/4 퍼센타일 길이: 6.0

# %%
print('형태소 최대길이: {}'.format(np.max(answer_sent_len_by_morph)))
print('형태소 최소길이: {}'.format(np.min(answer_sent_len_by_morph)))
print('형태소 평균길이: {:.2f}'.format(np.mean(answer_sent_len_by_morph)))
print('형태소 길이 표준편차: {:.2f}'.format(np.std(answer_sent_len_by_morph)))
print('형태소 중간길이: {}'.format(np.median(answer_sent_len_by_morph)))
print('형태소 1/4 퍼센타일 길이: {}'.format(np.percentile(answer_sent_len_by_morph, 25)))
print('형태소 3/4 퍼센타일 길이: {}'.format(np.percentile(answer_sent_len_by_morph, 75)))
# Out:
# 형태소 최대길이: 31
# 형태소 최소길이: 1
# 형태소 평균길이: 5.87
# 형태소 길이 표준편차: 2.55
# 형태소 중간길이: 5.0
# 형태소 1/4 퍼센타일 길이: 4.0
# 형태소 3/4 퍼센타일 길이: 7.0

# %%
okt.pos('오늘밤은유난히덥구나')
# Out:
# [('오늘밤', 'Noun'), ('은', 'Josa'), ('유난히', 'Adverb'), ('덥구나', 'Adjective')]

# %%
query_NVA_token_sentences = list()
answer_NVA_token_sentences = list()

for s in query_sentences:
    for token, tag in okt.pos(s.replace(' ', '')):
        if tag == 'Noun' or tag == 'Verb' or tag == 'Adjective':
            query_NVA_token_sentences.append(token)

for s in answer_sentences:
    temp_token_bucket = list()
    for token, tag in okt.pos(s.replace(' ', '')):
        if tag == 'Noun' or tag == 'Verb' or tag == 'Adjective':
            answer_NVA_token_sentences.append(token)

query_NVA_token_sentences = ' '.join(query_NVA_token_sentences)
answer_NVA_token_sentences = ' '.join(answer_NVA_token_sentences)

# %%
query_wordcloud = WordCloud(font_path= DATA_IN_PATH + 'NanumGothic.ttf').generate(query_NVA_token_sentences)

plt.imshow(query_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import sys
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import TextVectorization

# my_preprocess.py 파일이 있는 디렉토리를 sys.path에 추가
sys.path.append(os.path.abspath('path_to_preprocess_directory'))

# my_preprocess 모듈에서 필요한 함수 임포트
from my_preprocess import load_vocabulary, enc_processing, dec_output_processing, dec_target_processing, load_data

# %%
PATH = 'data_in/ChatBotData.csv_short'
VOCAB_PATH = 'data_in/vocabulary.txt'

# %%
inputs, outputs = load_data(PATH)

# %%
char2idx, idx2char, vocab_size = load_vocabulary(PATH, VOCAB_PATH, tokenize_as_morph=False)

# %%
index_inputs, input_seq_len = enc_processing(inputs, char2idx, tokenize_as_morph=False)
index_outputs, output_seq_len = dec_output_processing(outputs, char2idx, tokenize_as_morph=False)
index_targets = dec_target_processing(outputs, char2idx, tokenize_as_morph=False)

# %%
# my_preprocess 모듈에서 필요한 함수와 상수 임포트
from my_preprocess import (
    load_vocabulary,
    enc_processing,
    dec_output_processing,
    dec_target_processing,
    load_data,
    PAD,
    STD,
    END,
    UNK
)

data_configs = {}
data_configs['char2idx'] = char2idx
data_configs['idx2char'] = idx2char
data_configs['vocab_size'] = vocab_size
data_configs['pad_symbol'] = PAD
data_configs['std_symbol'] = STD
data_configs['end_symbol'] = END
data_configs['unk_symbol'] = UNK

# %%
import json  # json 모듈 임포트 추가

DATA_IN_PATH = './data_in/'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

np.save(open(DATA_IN_PATH + TRAIN_INPUTS, 'wb'), index_inputs)
np.save(open(DATA_IN_PATH + TRAIN_OUTPUTS , 'wb'), index_outputs)
np.save(open(DATA_IN_PATH + TRAIN_TARGETS , 'wb'), index_targets)

json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w'))

# %%
char2idx
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<END>': 2,
#  '<UNK>': 3,
#  '땀난다': 4,
#  '사람도': 5,
#  '운동을': 6,
#  '절약해봐요': 7,
#  '구하셨나요': 8,
#  '자의': 9,
#  '줄까': 10,
#  '승진': 11,
#  '때까지': 12,
#  '훈훈해': 13,
#  '그': 14,
#  '빨리': 15,
#  '돌아가서': 16,
#  '좋을까': 17,
#  '들어올': 18,
#  '빠를수록': 19,
#  '좀': 20,
#  '더': 21,
#  '선물로': 22,
#  '싶어': 23,
#  '달에는': 24,
#  '해': 25,
#  '필요한': 26,
#  '남자친구': 27,
#  '것': 28,
#  '망함': 29,
#  '바빠': 30,
#  '설움': 31,
#  '어서': 32,
#  '질린다': 33,
#  '다음': 34,
#  '설득해보세요': 35,
#  '가스불': 36,
#  '하세요': 37,
#  '끄고': 38,
#  '좋아요': 39,
#  '믿어줘': 40,
#  '나오세요': 41,
#  '운동만': 42,
#  '나왔다': 43,
#  '거짓말': 44,
#  '가끔은': 45,
#  '게': 46,
#  '운동': 47,
#  '집에': 48,
#  '걸리겠어': 49,
#  '비싼데': 50,
#  '좋을': 51,
#  '혼자인게': 52,
#  '나라를': 53,
#  '식혀주세요': 54,
#  '새출발': 55,
#  '적당히': 56,
#  '가끔': 57,
#  '가상화폐': 58,
#  '나갔어': 59,
#  '그럴': 60,
#  '교회': 61,
#  '보인다': 62,
#  '좋다': 63,
#  '갔어': 64,
#  '돈은': 65,
#  '거예요': 66,
#  '뭐가': 67,
#  '땀을': 68,
#  '너무': 69,
#  '따라': 70,
#  '가스비': 71,
#  '필요했던': 72,
#  '오늘': 73,
#  '사세요': 74,
#  '뭘': 75,
#  '집착하지': 76,
#  '같아요': 77,
#  '가난한': 78,
#  '나': 79,
#  '가만': 80,
#  '생일인데': 81,
#  '함께': 82,
#  '뭐하는지': 83,
#  '감기': 84,
#  '나온거': 85,
#  '따뜻하게': 86,
#  '남자친구가': 87,
#  '해보세요': 88,
#  '있어도': 89,
#  '결단은': 90,
#  '열': 91,
#  '같아': 92,
#  '켜놓고': 93,
#  '많이': 94,
#  '전생에': 95,
#  '생각해보세요': 96,
#  '마세요': 97,
#  '데려가고': 98,
#  '즐기세요': 99,
#  '또': 100,
#  '안': 101,
#  '다시': 102,
#  '마음을': 103,
#  '궁금해': 104,
#  '켜고': 105,
#  '잊고': 106,
#  '평소에': 107,
#  '잘생겼어': 108,
#  '쫄딱': 109,
#  '혼자를': 110}

# %%
idx2char
# Out:
# {0: '<PAD>',
#  1: '<SOS>',
#  2: '<END>',
#  3: '<UNK>',
#  4: '땀난다',
#  5: '사람도',
#  6: '운동을',
#  7: '절약해봐요',
#  8: '구하셨나요',
#  9: '자의',
#  10: '줄까',
#  11: '승진',
#  12: '때까지',
#  13: '훈훈해',
#  14: '그',
#  15: '빨리',
#  16: '돌아가서',
#  17: '좋을까',
#  18: '들어올',
#  19: '빠를수록',
#  20: '좀',
#  21: '더',
#  22: '선물로',
#  23: '싶어',
#  24: '달에는',
#  25: '해',
#  26: '필요한',
#  27: '남자친구',
#  28: '것',
#  29: '망함',
#  30: '바빠',
#  31: '설움',
#  32: '어서',
#  33: '질린다',
#  34: '다음',
#  35: '설득해보세요',
#  36: '가스불',
#  37: '하세요',
#  38: '끄고',
#  39: '좋아요',
#  40: '믿어줘',
#  41: '나오세요',
#  42: '운동만',
#  43: '나왔다',
#  44: '거짓말',
#  45: '가끔은',
#  46: '게',
#  47: '운동',
#  48: '집에',
#  49: '걸리겠어',
#  50: '비싼데',
#  51: '좋을',
#  52: '혼자인게',
#  53: '나라를',
#  54: '식혀주세요',
#  55: '새출발',
#  56: '적당히',
#  57: '가끔',
#  58: '가상화폐',
#  59: '나갔어',
#  60: '그럴',
#  61: '교회',
#  62: '보인다',
#  63: '좋다',
#  64: '갔어',
#  65: '돈은',
#  66: '거예요',
#  67: '뭐가',
#  68: '땀을',
#  69: '너무',
#  70: '따라',
#  71: '가스비',
#  72: '필요했던',
#  73: '오늘',
#  74: '사세요',
#  75: '뭘',
#  76: '집착하지',
#  77: '같아요',
#  78: '가난한',
#  79: '나',
#  80: '가만',
#  81: '생일인데',
#  82: '함께',
#  83: '뭐하는지',
#  84: '감기',
#  85: '나온거',
#  86: '따뜻하게',
#  87: '남자친구가',
#  88: '해보세요',
#  89: '있어도',
#  90: '결단은',
#  91: '열',
#  92: '같아',
#  93: '켜놓고',
#  94: '많이',
#  95: '전생에',
#  96: '생각해보세요',
#  97: '마세요',
#  98: '데려가고',
#  99: '즐기세요',
#  100: '또',
#  101: '안',
#  102: '다시',
#  103: '마음을',
#  104: '궁금해',
#  105: '켜고',
#  106: '잊고',
#  107: '평소에',
#  108: '잘생겼어',
#  109: '쫄딱',
#  110: '혼자를'}

# %% [markdown]
# 패키지 불러오기

# %%
import tensorflow as tf
import numpy as np
import os

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

from preprocess import *

# %% [markdown]
# 시각화 함수

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string], '')
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %% [markdown]
# 학습 데이터 경로 정의

# %%
DATA_IN_PATH = './data_in/'
DATA_OUT_PATH = './data_out/'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

# %% [markdown]
# 랜덤 시드 고정

# %%
SEED_NUM = 1234
tf.random.set_seed(SEED_NUM)

# %% [markdown]
# 파일 로드

# %%
index_inputs = np.load(open(DATA_IN_PATH + TRAIN_INPUTS, 'rb'))
index_outputs = np.load(open(DATA_IN_PATH + TRAIN_OUTPUTS , 'rb'))
index_targets = np.load(open(DATA_IN_PATH + TRAIN_TARGETS , 'rb'))
prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))

# %%
# Show length
print(len(index_inputs),  len(index_outputs), len(index_targets))
# Out:
# 20 20 20

# %% [markdown]
# 모델 만들기에 필요한 값 선언

# %%
MODEL_NAME = 'seq2seq_kor'
BATCH_SIZE = 2
MAX_SEQUENCE = 25
EPOCH = 30
UNITS = 1024
EMBEDDING_DIM = 256
VALIDATION_SPLIT = 0.1

char2idx = prepro_configs['char2idx']
idx2char = prepro_configs['idx2char']
std_index = prepro_configs['std_symbol']
end_index = prepro_configs['end_symbol']
vocab_size = prepro_configs['vocab_size']

# %% [markdown]
# ### 모델

# %% [markdown]
# 인코더

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim

        self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state = hidden)
        return output, state

    def initialize_hidden_state(self, inp):
        return tf.zeros((tf.shape(inp)[0], self.enc_units))

# %% [markdown]
# 어텐션

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        hidden_with_time_axis = tf.expand_dims(query, 1)

        score = self.V(tf.nn.tanh(
            self.W1(values) + self.W2(hidden_with_time_axis)))

        attention_weights = tf.nn.softmax(score, axis=1)

        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %% [markdown]
# 디코더

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()

        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim

        self.embedding = tf.keras.layers.Embedding(self.vocab_size, self.embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc = tf.keras.layers.Dense(self.vocab_size)

        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, hidden, enc_output):
        context_vector, attention_weights = self.attention(hidden, enc_output)

        x = self.embedding(x)

        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        output, state = self.gru(x)
        output = tf.reshape(output, (-1, output.shape[2]))

        x = self.fc(output)

        return x, state, attention_weights

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')

def loss(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

def accuracy(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    mask = tf.expand_dims(tf.cast(mask, dtype=pred.dtype), axis=-1)
    pred *= mask
    acc = train_accuracy(real, pred)

    return tf.reduce_mean(acc)

# %% [markdown]
# ### 시퀀스 투 스퀀스 모델

# %%
class seq2seq(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, dec_units, batch_sz, end_token_idx=2):
        super(seq2seq, self).__init__()
        self.end_token_idx = end_token_idx
        self.encoder = Encoder(vocab_size, embedding_dim, enc_units, batch_sz)
        self.decoder = Decoder(vocab_size, embedding_dim, dec_units, batch_sz)

    def call(self, x):
        inp, tar = x

        enc_hidden = self.encoder.initialize_hidden_state(inp)
        enc_output, enc_hidden = self.encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        predict_tokens = list()
        for t in range(0, tar.shape[1]):
            dec_input = tf.dtypes.cast(tf.expand_dims(tar[:, t], 1), tf.float32)
            predictions, dec_hidden, _ = self.decoder(dec_input, dec_hidden, enc_output)
            predict_tokens.append(tf.dtypes.cast(predictions, tf.float32))
        return tf.stack(predict_tokens, axis=1)

    def inference(self, x):
        inp  = x

        enc_hidden = self.encoder.initialize_hidden_state(inp)
        enc_output, enc_hidden = self.encoder(inp, enc_hidden)

        dec_hidden = enc_hidden

        dec_input = tf.expand_dims([char2idx[std_index]], 1)

        predict_tokens = list()
        for t in range(0, MAX_SEQUENCE):
            predictions, dec_hidden, _ = self.decoder(dec_input, dec_hidden, enc_output)
            predict_token = tf.argmax(predictions[0])

            if predict_token == self.end_token_idx:
                break

            predict_tokens.append(predict_token)
            dec_input = tf.dtypes.cast(tf.expand_dims([predict_token], 0), tf.float32)

        return tf.stack(predict_tokens, axis=0).numpy()

# %%
model = seq2seq(vocab_size, EMBEDDING_DIM, UNITS, UNITS, BATCH_SIZE, char2idx[end_index])
model.compile(loss=loss, optimizer=tf.keras.optimizers.Adam(1e-3), metrics=[accuracy])
#model.run_eagerly = True

# %% [markdown]
# ### 학습 진행

# %%
# 경로 설정
PATH = os.path.join(DATA_OUT_PATH, MODEL_NAME)
if not os.path.isdir(PATH):
    os.makedirs(PATH)

# 체크포인트 경로 설정
checkpoint_path = os.path.join(PATH, 'weights.weights.h5')

# 체크포인트 콜백 설정
cp_callback = ModelCheckpoint(
    checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True)

# 조기 종료 콜백 설정
earlystop_callback = EarlyStopping(monitor='val_accuracy', min_delta=0.0001, patience=10, mode='max')

# 모델 학습
history = model.fit([index_inputs, index_outputs], index_targets,
                    batch_size=BATCH_SIZE, epochs=EPOCH,
                    validation_split=VALIDATION_SPLIT, callbacks=[earlystop_callback, cp_callback])
# Out:
# Epoch 1/30
# 9/9 [==============================] - ETA: 0s - loss: 0.8261 - accuracy: 0.8360
# Epoch 1: val_accuracy improved from -inf to 0.85400, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 38s 1s/step - loss: 0.8261 - accuracy: 0.8360 - val_loss: 0.6485 - val_accuracy: 0.8540
# Epoch 2/30
# 9/9 [==============================] - ETA: 0s - loss: 0.7367 - accuracy: 0.8527
# Epoch 2: val_accuracy improved from 0.85400 to 0.85600, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.7367 - accuracy: 0.8527 - val_loss: 0.6225 - val_accuracy: 0.8560
# Epoch 3/30
# 9/9 [==============================] - ETA: 0s - loss: 0.6627 - accuracy: 0.8572
# Epoch 3: val_accuracy improved from 0.85600 to 0.85667, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.6627 - accuracy: 0.8572 - val_loss: 0.5767 - val_accuracy: 0.8567
# Epoch 4/30
# 9/9 [==============================] - ETA: 0s - loss: 0.6226 - accuracy: 0.8572
# Epoch 4: val_accuracy improved from 0.85667 to 0.85700, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 469ms/step - loss: 0.6226 - accuracy: 0.8572 - val_loss: 0.5541 - val_accuracy: 0.8570
# Epoch 5/30
# 9/9 [==============================] - ETA: 0s - loss: 0.5773 - accuracy: 0.8573
# Epoch 5: val_accuracy improved from 0.85700 to 0.85720, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.5773 - accuracy: 0.8573 - val_loss: 0.5055 - val_accuracy: 0.8572
# Epoch 6/30
# 9/9 [==============================] - ETA: 0s - loss: 0.5268 - accuracy: 0.8568
# Epoch 6: val_accuracy improved from 0.85720 to 0.85767, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 444ms/step - loss: 0.5268 - accuracy: 0.8568 - val_loss: 0.4523 - val_accuracy: 0.8577
# Epoch 7/30
# 9/9 [==============================] - ETA: 0s - loss: 0.4719 - accuracy: 0.8586
# Epoch 7: val_accuracy improved from 0.85767 to 0.86000, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 445ms/step - loss: 0.4719 - accuracy: 0.8586 - val_loss: 0.4199 - val_accuracy: 0.8600
# Epoch 8/30
# 9/9 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8629
# Epoch 8: val_accuracy improved from 0.86000 to 0.86475, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 448ms/step - loss: 0.4246 - accuracy: 0.8629 - val_loss: 0.3718 - val_accuracy: 0.8648
# Epoch 9/30
# 9/9 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.8682
# Epoch 9: val_accuracy improved from 0.86475 to 0.87178, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 439ms/step - loss: 0.3631 - accuracy: 0.8682 - val_loss: 0.3310 - val_accuracy: 0.8718
# Epoch 10/30
# 9/9 [==============================] - ETA: 0s - loss: 0.3229 - accuracy: 0.8757
# Epoch 10: val_accuracy improved from 0.87178 to 0.87960, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 446ms/step - loss: 0.3229 - accuracy: 0.8757 - val_loss: 0.3083 - val_accuracy: 0.8796
# Epoch 11/30
# 9/9 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.8831
# Epoch 11: val_accuracy improved from 0.87960 to 0.88582, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.2789 - accuracy: 0.8831 - val_loss: 0.2326 - val_accuracy: 0.8858
# Epoch 12/30
# 9/9 [==============================] - ETA: 0s - loss: 0.2298 - accuracy: 0.8890
# Epoch 12: val_accuracy improved from 0.88582 to 0.89183, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.2298 - accuracy: 0.8890 - val_loss: 0.2138 - val_accuracy: 0.8918
# Epoch 13/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1968 - accuracy: 0.8944
# Epoch 13: val_accuracy improved from 0.89183 to 0.89677, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.1968 - accuracy: 0.8944 - val_loss: 0.2241 - val_accuracy: 0.8968
# Epoch 14/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.8991
# Epoch 14: val_accuracy improved from 0.89677 to 0.90100, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 444ms/step - loss: 0.1808 - accuracy: 0.8991 - val_loss: 0.1206 - val_accuracy: 0.9010
# Epoch 15/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9029
# Epoch 15: val_accuracy improved from 0.90100 to 0.90453, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 447ms/step - loss: 0.1563 - accuracy: 0.9029 - val_loss: 0.1430 - val_accuracy: 0.9045
# Epoch 16/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9064
# Epoch 16: val_accuracy improved from 0.90453 to 0.90800, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 444ms/step - loss: 0.1465 - accuracy: 0.9064 - val_loss: 0.1177 - val_accuracy: 0.9080
# Epoch 17/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9096
# Epoch 17: val_accuracy improved from 0.90800 to 0.91106, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 486ms/step - loss: 0.1343 - accuracy: 0.9096 - val_loss: 0.1349 - val_accuracy: 0.9111
# Epoch 18/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9124
# Epoch 18: val_accuracy improved from 0.91106 to 0.91367, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 445ms/step - loss: 0.1315 - accuracy: 0.9124 - val_loss: 0.1320 - val_accuracy: 0.9137
# Epoch 19/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9148
# Epoch 19: val_accuracy improved from 0.91367 to 0.91579, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 446ms/step - loss: 0.1226 - accuracy: 0.9148 - val_loss: 0.1215 - val_accuracy: 0.9158
# Epoch 20/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9170
# Epoch 20: val_accuracy improved from 0.91579 to 0.91800, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 446ms/step - loss: 0.1129 - accuracy: 0.9170 - val_loss: 0.1129 - val_accuracy: 0.9180
# Epoch 21/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1182 - accuracy: 0.9190
# Epoch 21: val_accuracy improved from 0.91800 to 0.92000, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 445ms/step - loss: 0.1182 - accuracy: 0.9190 - val_loss: 0.1204 - val_accuracy: 0.9200
# Epoch 22/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9211
# Epoch 22: val_accuracy improved from 0.92000 to 0.92209, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.1070 - accuracy: 0.9211 - val_loss: 0.1106 - val_accuracy: 0.9221
# Epoch 23/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9233
# Epoch 23: val_accuracy improved from 0.92209 to 0.92426, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 448ms/step - loss: 0.0885 - accuracy: 0.9233 - val_loss: 0.1415 - val_accuracy: 0.9243
# Epoch 24/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9253
# Epoch 24: val_accuracy improved from 0.92426 to 0.92633, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 446ms/step - loss: 0.0752 - accuracy: 0.9253 - val_loss: 0.1262 - val_accuracy: 0.9263
# Epoch 25/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9276
# Epoch 25: val_accuracy improved from 0.92633 to 0.92856, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 444ms/step - loss: 0.0570 - accuracy: 0.9276 - val_loss: 0.0979 - val_accuracy: 0.9286
# Epoch 26/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9298
# Epoch 26: val_accuracy improved from 0.92856 to 0.93092, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.0301 - accuracy: 0.9298 - val_loss: 0.1623 - val_accuracy: 0.9309
# Epoch 27/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9322
# Epoch 27: val_accuracy improved from 0.93092 to 0.93326, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 441ms/step - loss: 0.0165 - accuracy: 0.9322 - val_loss: 0.2406 - val_accuracy: 0.9333
# Epoch 28/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 0.9342
# Epoch 28: val_accuracy improved from 0.93326 to 0.93507, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 444ms/step - loss: 0.0625 - accuracy: 0.9342 - val_loss: 0.2380 - val_accuracy: 0.9351
# Epoch 29/30
# 9/9 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9358
# Epoch 29: val_accuracy improved from 0.93507 to 0.93614, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 442ms/step - loss: 0.1112 - accuracy: 0.9358 - val_loss: 0.4816 - val_accuracy: 0.9361
# Epoch 30/30
# 9/9 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9368
# Epoch 30: val_accuracy improved from 0.93614 to 0.93753, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 [==============================] - 4s 446ms/step - loss: 0.0687 - accuracy: 0.9368 - val_loss: 0.3041 - val_accuracy: 0.9375

# %% [markdown]
# ### 결과 플롯

# %%
plot_graphs(history, 'accuracy')

# %%
plot_graphs(history, 'loss')

# %% [markdown]
# ### 결과 확인

# %%
# 가중치 파일 이름
SAVE_FILE_NM = "weights.weights.h5"

# 가중치 파일 경로 설정
weights_path = os.path.join(DATA_OUT_PATH, MODEL_NAME, SAVE_FILE_NM)

# 모델 가중치 로드
model.load_weights(weights_path)

# %%
query = "남자친구 승진 선물로 뭐가 좋을까?"

test_index_inputs, _ = enc_processing([query], char2idx)
predict_tokens = model.inference(test_index_inputs)
print(predict_tokens)

print(' '.join([idx2char[str(t)] for t in predict_tokens]))
# Out:
# [107  72  46  51  28  77]
# 평소에 필요했던 게 좋을 것 같아요

# %% [markdown]
# ### 모듈 불러오기

# %%
import tensorflow as tf
import numpy as np

from konlpy.tag import Twitter
import pandas as pd
import tensorflow as tf
import enum
import os
import re
import json
from sklearn.model_selection import train_test_split

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

from preprocess import *

# %% [markdown]
# ### 시각화 함수

# %%
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string], '')
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %% [markdown]
# ### 학습 데이터 경로 정의

# %%
DATA_IN_PATH = './data_in/'
DATA_OUT_PATH = './data_out/'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

# %% [markdown]
# ### 랜덤 시드 고정

# %%
SEED_NUM = 1234
tf.random.set_seed(SEED_NUM)

# %% [markdown]
# ### 파일 로드

# %%
index_inputs = np.load(open(DATA_IN_PATH + TRAIN_INPUTS, 'rb'))
index_outputs = np.load(open(DATA_IN_PATH + TRAIN_OUTPUTS , 'rb'))
index_targets = np.load(open(DATA_IN_PATH + TRAIN_TARGETS , 'rb'))
prepro_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))

# %% [markdown]
# ### 모델 하이퍼파라메터 정의

# %%
char2idx = prepro_configs['char2idx']
end_index = prepro_configs['end_symbol']
model_name = 'transformer'
vocab_size = prepro_configs['vocab_size']
BATCH_SIZE = 2
MAX_SEQUENCE = 25
EPOCHS = 30
VALID_SPLIT = 0.1

kargs = {'model_name': model_name,
         'num_layers': 2,
         'd_model': 512,
         'num_heads': 8,
         'dff': 2048,
         'input_vocab_size': vocab_size,
         'target_vocab_size': vocab_size,
         'maximum_position_encoding': MAX_SEQUENCE,
         'end_token_idx': char2idx[end_index],
         'rate': 0.1
        }

# %% [markdown]
# ### 모델 선언 및 컴파일

# %% [markdown]
# ### 패딩 및 포워드 마스킹

# %%
def create_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)

    # add extra dimensions to add the padding
    # to the attention logits.
    return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
    mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
    return mask  # (seq_len, seq_len)

# %%
def create_masks(inp, tar):
    # Encoder padding mask
    enc_padding_mask = create_padding_mask(inp)

    # Used in the 2nd attention block in the decoder.
    # This padding mask is used to mask the encoder outputs.
    dec_padding_mask = create_padding_mask(inp)

    # Used in the 1st attention block in the decoder.
    # It is used to pad and mask future tokens in the input received by
    # the decoder.
    look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
    dec_target_padding_mask = create_padding_mask(tar)
    combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)

    return enc_padding_mask, combined_mask, dec_padding_mask

# %%
enc_padding_mask, look_ahead_mask, dec_padding_mask = create_masks(index_inputs, index_outputs)

# %% [markdown]
# ### 포지셔널 인코딩

# %%
def get_angles(pos, i, d_model):
    angle_rates = 1 / np.power(10000, (2 * i//2) / np.float32(d_model))
    return pos * angle_rates

# %%
def positional_encoding(position, d_model):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

    pos_encoding = angle_rads[np.newaxis, ...]

    return tf.cast(pos_encoding, dtype=tf.float32)

# %%
pos_encoding = positional_encoding(50, 512)
print (pos_encoding.shape)

plt.pcolormesh(pos_encoding[0], cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, 512))
plt.ylabel('Position')
plt.colorbar()
plt.show()
# Out:
# (1, 50, 512)

# %% [markdown]
# ### 어텐션

# %%
def scaled_dot_product_attention(q, k, v, mask):
    """Calculate the attention weights.
    q, k, v must have matching leading dimensions.
    k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
    The mask has different shapes depending on its type(padding or look ahead)
    but it must be broadcastable for addition.

    Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

    Returns:
    output, attention_weights
    """

    matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

    # scale matmul_qk
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    # add the mask to the scaled tensor.
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)

    # softmax is normalized on the last axis (seq_len_k) so that the scores
    # add up to 1.
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

    output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

    return output, attention_weights

# %% [markdown]
# ### 멀티헤드 어텐션

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, **kargs):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = kargs['num_heads']
        self.d_model = kargs['d_model']

        assert self.d_model % self.num_heads == 0

        self.depth = self.d_model // self.num_heads

        self.wq = tf.keras.layers.Dense(kargs['d_model'])
        self.wk = tf.keras.layers.Dense(kargs['d_model'])
        self.wv = tf.keras.layers.Dense(kargs['d_model'])

        self.dense = tf.keras.layers.Dense(kargs['d_model'])

    def split_heads(self, x, batch_size):
        """Split the last dimension into (num_heads, depth).
        Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
        """
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]

        q = self.wq(q)  # (batch_size, seq_len, d_model)
        k = self.wk(k)  # (batch_size, seq_len, d_model)
        v = self.wv(v)  # (batch_size, seq_len, d_model)

        q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
        k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
        v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

        # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
        # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
        scaled_attention, attention_weights = scaled_dot_product_attention(
            q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

        concat_attention = tf.reshape(scaled_attention,
                                      (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

        output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

        return output, attention_weights

# %% [markdown]
# ### 포인트 와이즈 피드포워드 네트워크

# %%
def point_wise_feed_forward_network(**kargs):
    return tf.keras.Sequential([
      tf.keras.layers.Dense(kargs['dff'], activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(kargs['d_model'])  # (batch_size, seq_len, d_model)
    ])

# %% [markdown]
# ### 인코더 레이어

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, **kargs):
        super(EncoderLayer, self).__init__()

        self.mha = MultiHeadAttention(**kargs)
        self.ffn = point_wise_feed_forward_network(**kargs)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(kargs['rate'])
        self.dropout2 = tf.keras.layers.Dropout(kargs['rate'])

    def call(self, x, mask):
        attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)

        return out2

# %% [markdown]
# ### 디코더 레이어

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, **kargs):
        super(DecoderLayer, self).__init__()

        self.mha1 = MultiHeadAttention(**kargs)
        self.mha2 = MultiHeadAttention(**kargs)

        self.ffn = point_wise_feed_forward_network(**kargs)

        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.dropout1 = tf.keras.layers.Dropout(kargs['rate'])
        self.dropout2 = tf.keras.layers.Dropout(kargs['rate'])
        self.dropout3 = tf.keras.layers.Dropout(kargs['rate'])


    def call(self, x, enc_output, look_ahead_mask, padding_mask):
        # enc_output.shape == (batch_size, input_seq_len, d_model)
        attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
        attn1 = self.dropout1(attn1)
        out1 = self.layernorm1(attn1 + x)

        attn2, attn_weights_block2 = self.mha2(
            enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
        attn2 = self.dropout2(attn2)
        out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

        ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
        ffn_output = self.dropout3(ffn_output)
        out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

        return out3, attn_weights_block1, attn_weights_block2

# %% [markdown]
# ### 인코더

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, **kargs):
        super(Encoder, self).__init__()

        self.d_model = kargs['d_model']
        self.num_layers = kargs['num_layers']

        self.embedding = tf.keras.layers.Embedding(kargs['input_vocab_size'], self.d_model)
        self.pos_encoding = positional_encoding(kargs['maximum_position_encoding'],
                                                self.d_model)


        self.enc_layers = [EncoderLayer(**kargs)
                           for _ in range(self.num_layers)]

        self.dropout = tf.keras.layers.Dropout(kargs['rate'])

    def call(self, x, mask):

        seq_len = tf.shape(x)[1]

        # adding embedding and position encoding.
        x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x)

        for i in range(self.num_layers):
            x = self.enc_layers[i](x, mask)

        return x  # (batch_size, input_seq_len, d_model)

# %% [markdown]
# ### 디코더

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, **kargs):
        super(Decoder, self).__init__()

        self.d_model = kargs['d_model']
        self.num_layers = kargs['num_layers']

        self.embedding = tf.keras.layers.Embedding(kargs['target_vocab_size'], self.d_model)
        self.pos_encoding = positional_encoding(kargs['maximum_position_encoding'], self.d_model)

        self.dec_layers = [DecoderLayer(**kargs)
                           for _ in range(self.num_layers)]
        self.dropout = tf.keras.layers.Dropout(kargs['rate'])

    def call(self, x, enc_output, look_ahead_mask, padding_mask):
        seq_len = tf.shape(x)[1]
        attention_weights = {}

        x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x += self.pos_encoding[:, :seq_len, :]

        x = self.dropout(x)

        for i in range(self.num_layers):
            x, block1, block2 = self.dec_layers[i](x, enc_output, look_ahead_mask, padding_mask)

            attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
            attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

        # x.shape == (batch_size, target_seq_len, d_model)
        return x, attention_weights

# %% [markdown]
# ### 트렌스포머 모델

# %%
class Transformer(tf.keras.Model):
    def __init__(self, **kargs):
        super(Transformer, self).__init__(name=kargs['model_name'])
        self.end_token_idx = kargs['end_token_idx']

        self.encoder = Encoder(**kargs)
        self.decoder = Decoder(**kargs)

        self.final_layer = tf.keras.layers.Dense(kargs['target_vocab_size'])

    def call(self, x):
        inp, tar = x

        enc_padding_mask, look_ahead_mask, dec_padding_mask = create_masks(inp, tar)
        enc_output = self.encoder(inp, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)

        # dec_output.shape == (batch_size, tar_seq_len, d_model)
        dec_output, _ = self.decoder(
            tar, enc_output, look_ahead_mask, dec_padding_mask)

        final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)

        return final_output

    def inference(self, x):
        inp = x
        tar = tf.expand_dims([STD_INDEX], 0)

        enc_padding_mask, look_ahead_mask, dec_padding_mask = create_masks(inp, tar)
        enc_output = self.encoder(inp, enc_padding_mask)

        predict_tokens = list()
        for t in range(0, MAX_SEQUENCE):
            dec_output, _ = self.decoder(tar, enc_output, look_ahead_mask, dec_padding_mask)
            final_output = self.final_layer(dec_output)
            outputs = tf.argmax(final_output, -1).numpy()
            pred_token = outputs[0][-1]
            if pred_token == self.end_token_idx:
                break
            predict_tokens.append(pred_token)
            tar = tf.expand_dims([STD_INDEX] + predict_tokens, 0)
            _, look_ahead_mask, dec_padding_mask = create_masks(inp, tar)

        return predict_tokens

# %% [markdown]
# ### 모델 로스 정의

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')

def loss(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

def accuracy(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    mask = tf.expand_dims(tf.cast(mask, dtype=pred.dtype), axis=-1)
    pred *= mask
    acc = train_accuracy(real, pred)

    return tf.reduce_mean(acc)

# %%
model = Transformer(**kargs)
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=loss,
              metrics=[accuracy])

# %% [markdown]
# ### Callback 선언과 학습

# %%
# EarlyStopping 콜백 설정 (과적합 방지)
earlystop_callback = EarlyStopping(
    monitor='val_accuracy', min_delta=0.0001, patience=10, mode='max', verbose=1)

# 체크포인트 경로 설정
checkpoint_path = os.path.join(DATA_OUT_PATH, MODEL_NAME, 'weights.weights.h5')
checkpoint_dir = os.path.dirname(checkpoint_path)

# 경로가 존재하는지 확인하고, 없으면 생성
if os.path.exists(checkpoint_dir):
    print(f"{checkpoint_dir} -- Folder already exists \n")
else:
    os.makedirs(checkpoint_dir, exist_ok=True)
    print(f"{checkpoint_dir} -- Folder created \n")

# ModelCheckpoint 콜백 설정 (최적 가중치 저장)
cp_callback = ModelCheckpoint(
    checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=True)

# 모델 학습
history = model.fit(
    [index_inputs, index_outputs], index_targets,
    batch_size=BATCH_SIZE, epochs=EPOCH,
    validation_split=VALIDATION_SPLIT,
    callbacks=[earlystop_callback, cp_callback]
)
# Out:
# ./data_out/seq2seq_kor -- Folder already exists
#
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8062 - loss: 1.0670
# Epoch 1: val_accuracy improved from -inf to 0.85000, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 22s 372ms/step - accuracy: 0.8084 - loss: 1.0539 - val_accuracy: 0.8500 - val_loss: 0.5518
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8479 - loss: 0.5940
# Epoch 2: val_accuracy improved from 0.85000 to 0.85500, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.8482 - loss: 0.5906 - val_accuracy: 0.8550 - val_loss: 0.5577
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8577 - loss: 0.4336
# Epoch 3: val_accuracy improved from 0.85500 to 0.87067, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.8581 - loss: 0.4275 - val_accuracy: 0.8707 - val_loss: 0.6112
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8769 - loss: 0.2026
# Epoch 4: val_accuracy improved from 0.87067 to 0.88650, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - accuracy: 0.8773 - loss: 0.2014 - val_accuracy: 0.8865 - val_loss: 0.7647
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8909 - loss: 0.2415
# Epoch 5: val_accuracy improved from 0.88650 to 0.89440, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.8911 - loss: 0.2492 - val_accuracy: 0.8944 - val_loss: 0.5857
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8966 - loss: 0.2413
# Epoch 6: val_accuracy improved from 0.89440 to 0.90167, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.8967 - loss: 0.2409 - val_accuracy: 0.9017 - val_loss: 0.5259
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9045 - loss: 0.1353
# Epoch 7: val_accuracy improved from 0.90167 to 0.91086, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9047 - loss: 0.1329 - val_accuracy: 0.9109 - val_loss: 0.3546
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9141 - loss: 0.0379
# Epoch 8: val_accuracy improved from 0.91086 to 0.91950, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.9143 - loss: 0.0377 - val_accuracy: 0.9195 - val_loss: 0.3698
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9223 - loss: 0.0150
# Epoch 9: val_accuracy improved from 0.91950 to 0.92689, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - accuracy: 0.9225 - loss: 0.0149 - val_accuracy: 0.9269 - val_loss: 0.4279
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9292 - loss: 0.0045
# Epoch 10: val_accuracy improved from 0.92689 to 0.93300, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.9294 - loss: 0.0044 - val_accuracy: 0.9330 - val_loss: 0.4393
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9349 - loss: 0.0029
# Epoch 11: val_accuracy improved from 0.93300 to 0.93818, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9350 - loss: 0.0028 - val_accuracy: 0.9382 - val_loss: 0.4365
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9398 - loss: 0.0020
# Epoch 12: val_accuracy improved from 0.93818 to 0.94250, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 197ms/step - accuracy: 0.9399 - loss: 0.0020 - val_accuracy: 0.9425 - val_loss: 0.4307
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9439 - loss: 0.0015
# Epoch 13: val_accuracy improved from 0.94250 to 0.94615, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - accuracy: 0.9440 - loss: 0.0015 - val_accuracy: 0.9462 - val_loss: 0.4254
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9474 - loss: 0.0013
# Epoch 14: val_accuracy improved from 0.94615 to 0.94929, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.9474 - loss: 0.0013 - val_accuracy: 0.9493 - val_loss: 0.4215
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9503 - loss: 0.0011
# Epoch 15: val_accuracy improved from 0.94929 to 0.95200, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 233ms/step - accuracy: 0.9504 - loss: 0.0011 - val_accuracy: 0.9520 - val_loss: 0.4189
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9529 - loss: 0.0010
# Epoch 16: val_accuracy improved from 0.95200 to 0.95437, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.9530 - loss: 9.9434e-04 - val_accuracy: 0.9544 - val_loss: 0.4174
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9552 - loss: 9.1556e-04
# Epoch 17: val_accuracy improved from 0.95437 to 0.95647, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9553 - loss: 9.0619e-04 - val_accuracy: 0.9565 - val_loss: 0.4163
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9572 - loss: 8.4235e-04
# Epoch 18: val_accuracy improved from 0.95647 to 0.95833, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9573 - loss: 8.3383e-04 - val_accuracy: 0.9583 - val_loss: 0.4154
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9590 - loss: 7.8006e-04
# Epoch 19: val_accuracy improved from 0.95833 to 0.96000, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - accuracy: 0.9591 - loss: 7.7224e-04 - val_accuracy: 0.9600 - val_loss: 0.4146
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9606 - loss: 7.2604e-04
# Epoch 20: val_accuracy improved from 0.96000 to 0.96150, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 195ms/step - accuracy: 0.9607 - loss: 7.1882e-04 - val_accuracy: 0.9615 - val_loss: 0.4140
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9621 - loss: 6.7841e-04
# Epoch 21: val_accuracy improved from 0.96150 to 0.96286, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - accuracy: 0.9621 - loss: 6.7172e-04 - val_accuracy: 0.9629 - val_loss: 0.4134
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9634 - loss: 6.3590e-04
# Epoch 22: val_accuracy improved from 0.96286 to 0.96418, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.9634 - loss: 6.2968e-04 - val_accuracy: 0.9642 - val_loss: 0.4129
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9647 - loss: 5.9773e-04
# Epoch 23: val_accuracy improved from 0.96418 to 0.96539, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.9647 - loss: 5.9192e-04 - val_accuracy: 0.9654 - val_loss: 0.4126
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9658 - loss: 5.6328e-04
# Epoch 24: val_accuracy improved from 0.96539 to 0.96650, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - accuracy: 0.9659 - loss: 5.5785e-04 - val_accuracy: 0.9665 - val_loss: 0.4122
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9669 - loss: 5.3202e-04
# Epoch 25: val_accuracy improved from 0.96650 to 0.96752, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.9669 - loss: 5.2693e-04 - val_accuracy: 0.9675 - val_loss: 0.4119
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9679 - loss: 5.0353e-04
# Epoch 26: val_accuracy improved from 0.96752 to 0.96846, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9679 - loss: 4.9874e-04 - val_accuracy: 0.9685 - val_loss: 0.4115
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9688 - loss: 4.7746e-04
# Epoch 27: val_accuracy improved from 0.96846 to 0.96933, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.9688 - loss: 4.7296e-04 - val_accuracy: 0.9693 - val_loss: 0.4111
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9697 - loss: 4.5354e-04
# Epoch 28: val_accuracy improved from 0.96933 to 0.97014, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9697 - loss: 4.4929e-04 - val_accuracy: 0.9701 - val_loss: 0.4108
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9705 - loss: 4.3149e-04
# Epoch 29: val_accuracy improved from 0.97014 to 0.97090, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - accuracy: 0.9705 - loss: 4.2747e-04 - val_accuracy: 0.9709 - val_loss: 0.4104
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9712 - loss: 4.1114e-04
# Epoch 30: val_accuracy improved from 0.97090 to 0.97160, saving model to ./data_out/seq2seq_kor\weights.weights.h5
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.9712 - loss: 4.0734e-04 - val_accuracy: 0.9716 - val_loss: 0.4100

# %% [markdown]
# ### 결과 플롯

# %%
plot_graphs(history, 'accuracy')

# %%
plot_graphs(history, 'loss')

# %% [markdown]
# ### 베스트 모델 불러오기

# %%
SAVE_FILE_NM = "weights.weights.h5"

# 가중치 파일 경로 설정
weights_path = os.path.join(DATA_OUT_PATH, MODEL_NAME, SAVE_FILE_NM)

# 모델 가중치 로드
model.load_weights(weights_path)

# %% [markdown]
# ### 모델 결과 출력하기

# %%
char2idx = prepro_configs['char2idx']
idx2char = prepro_configs['idx2char']

# %%
# my_preprocess 모듈에서 필요한 함수와 상수 임포트
from my_preprocess import (
    STD_INDEX  # STD_INDEX 상수 임포트
)

text = "남자친구 승진 선물로 뭐가 좋을까?"
test_index_inputs, _ = enc_processing([text], char2idx)
outputs = model.inference(test_index_inputs)

print(' '.join([idx2char[str(o)] for o in outputs]))
# Out:
# 평소에 필요했던 게 좋을 것 같아요
