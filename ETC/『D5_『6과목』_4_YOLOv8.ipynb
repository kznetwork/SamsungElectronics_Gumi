# %% [markdown]
# # 『D5-『6과목』-4-YOLOv8.

# %% [markdown]
# ## Set Up

# %%
import tensorflow as tf

print(tf.executing_eagerly())

# %%
import tensorflow as tf

tf.config.run_functions_eagerly(True)

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('C:\\DEV\\YOLOv8Pro\\runs\\detect\\train19\\weights\\best.pt')  # pretrained YOLOv8n model

# Define image file path
image_folder = 'C:\\DEV\\YOLOv8Pro\\images\\'

# Define image file names
image_file_1 = '51df913aec6e6cf119d01ca48a9d6664-770xAAA.png'
image_file_2 = '23ppiicc170425.png'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs
# Out:
# 0: 640x640 3 p_cameras, 741.5ms
# 1: 640x640 1 p_camera, 741.5ms
# Speed: 8.4ms preprocess, 741.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import cv2
# Load a model
model = YOLO('C:\\DEV\\YOLOv8Pro\\runs\\detect\\train19\\weights\\best.pt')  # pretrained YOLOv8n model

model.predict(source="0", show=True, stream=True, classes=0)  # [0, 3, 5] for multiple classes


# Define image file path
image_folder = 'C:\\DEV\\YOLOv8Pro\\images\\'

# Define image file names
image_file_1 = '51df913aec6e6cf119d01ca48a9d6664-770xAAA.png'
image_file_2 = '23ppiicc170425.png'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects
model.predict(source="0", show=True, stream=True, classes=0)

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs

    # Print box coordinates
    print("Box coordinates:")
    for box in boxes:
        print(box)

    # Display result with boxes
    result.plot()
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# 0: 640x640 3 p_cameras, 712.1ms
# 1: 640x640 1 p_camera, 712.1ms
# Speed: 0.0ms preprocess, 712.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.9983])
# data: tensor([[392.4664,  26.5937, 461.4152, 156.7043,   0.9983,   0.0000]])
# id: None
# is_track: False
# orig_shape: (498, 770)
# shape: torch.Size([1, 6])
# xywh: tensor([[426.9408,  91.6490,  68.9488, 130.1107]])
# xywhn: tensor([[0.5545, 0.1840, 0.0895, 0.2613]])
# xyxy: tensor([[392.4664,  26.5937, 461.4152, 156.7043]])
# xyxyn: tensor([[0.5097, 0.0534, 0.5992, 0.3147]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.9971])
# data: tensor([[255.8702,  23.9802, 332.7969, 157.4290,   0.9971,   0.0000]])
# id: None
# is_track: False
# orig_shape: (498, 770)
# shape: torch.Size([1, 6])
# xywh: tensor([[294.3336,  90.7046,  76.9267, 133.4488]])
# xywhn: tensor([[0.3823, 0.1821, 0.0999, 0.2680]])
# xyxy: tensor([[255.8702,  23.9802, 332.7969, 157.4290]])
# xyxyn: tensor([[0.3323, 0.0482, 0.4322, 0.3161]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.9970])
# data: tensor([[121.2967,  26.9259, 195.1665, 163.2960,   0.9970,   0.0000]])
# id: None
# is_track: False
# orig_shape: (498, 770)
# shape: torch.Size([1, 6])
# xywh: tensor([[158.2316,  95.1109,  73.8698, 136.3701]])
# xywhn: tensor([[0.2055, 0.1910, 0.0959, 0.2738]])
# xyxy: tensor([[121.2967,  26.9259, 195.1665, 163.2960]])
# xyxyn: tensor([[0.1575, 0.0541, 0.2535, 0.3279]])
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.4492])
# data: tensor([[4.7040e+02, 7.1061e+01, 4.9364e+02, 9.8377e+01, 4.4919e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (335, 596)
# shape: torch.Size([1, 6])
# xywh: tensor([[482.0189,  84.7189,  23.2383,  27.3156]])
# xywhn: tensor([[0.8088, 0.2529, 0.0390, 0.0815]])
# xyxy: tensor([[470.3997,  71.0611, 493.6380,  98.3767]])
# xyxyn: tensor([[0.7893, 0.2121, 0.8283, 0.2937]])

# %% [markdown]
# ## 객체 검출-YOLO

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model

# Define image file path
image_folder = 'C:\\DEV\\SamsungElectronics_Gumi\\datasets\\YOLO\\'

# Define image file names
image_file_1 = 'im1.jpg'
image_file_2 = 'im2.jpg'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs
# Out:
# 0: 640x640 3 persons, 3 bicycles, 1 bench, 1 dog, 146.8ms
# 1: 640x640 4 persons, 146.8ms
# Speed: 6.2ms preprocess, 146.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# #

# %%
from ultralytics import YOLO
import cv2
# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model
model.predict(source="0", show=True, stream=True, classes=0)  # [0, 3, 5] for multiple classes


# Define image file path
image_folder = 'C:\\DEV\\YOLOv8Pro\\train_data\\'

# Define image file names
image_file_1 = '20190621_092709.png'
image_file_2 = '23ppiicc170425.png'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects
model.predict(source="0", show=True, stream=True, classes=0)

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs

    # Print box coordinates
    print("Box coordinates:")
    for box in boxes:
        print(box)

    # Display result with boxes
    result.plot()
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# 0: 640x640 1 person, 142.3ms
# 1: 640x640 2 persons, 142.3ms
# Speed: 0.0ms preprocess, 142.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6658])
# data: tensor([[4.6122e+02, 2.2501e+02, 7.5907e+02, 5.5580e+02, 6.6575e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (562, 800)
# shape: torch.Size([1, 6])
# xywh: tensor([[610.1486, 390.4080, 297.8483, 330.7870]])
# xywhn: tensor([[0.7627, 0.6947, 0.3723, 0.5886]])
# xyxy: tensor([[461.2244, 225.0145, 759.0727, 555.8015]])
# xyxyn: tensor([[0.5765, 0.4004, 0.9488, 0.9890]])
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.9214])
# data: tensor([[351.2473,  22.8303, 596.0000, 332.3400,   0.9214,   0.0000]])
# id: None
# is_track: False
# orig_shape: (335, 596)
# shape: torch.Size([1, 6])
# xywh: tensor([[473.6237, 177.5852, 244.7527, 309.5096]])
# xywhn: tensor([[0.7947, 0.5301, 0.4107, 0.9239]])
# xyxy: tensor([[351.2473,  22.8303, 596.0000, 332.3400]])
# xyxyn: tensor([[0.5893, 0.0682, 1.0000, 0.9921]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.9166])
# data: tensor([[194.2920, 107.6119, 299.0507, 256.7367,   0.9166,   0.0000]])
# id: None
# is_track: False
# orig_shape: (335, 596)
# shape: torch.Size([1, 6])
# xywh: tensor([[246.6713, 182.1743, 104.7587, 149.1248]])
# xywhn: tensor([[0.4139, 0.5438, 0.1758, 0.4451]])
# xyxy: tensor([[194.2920, 107.6119, 299.0507, 256.7367]])
# xyxyn: tensor([[0.3260, 0.3212, 0.5018, 0.7664]])

# %% [markdown]
# # 특정 사물만 인식

# %%
from ultralytics import YOLO
import cv2
# Load a model
model = YOLO('yolov8n.pt')  # pretrained YOLOv8n model
model.predict(source="0", show=True, stream=True, classes=0)  # [0, 3, 5] for multiple classes

# Define image file path
image_folder = 'C:\\DEV\\SamsungElectronics_Gumi\\datasets\\YOLO\\'

# Define image file names
image_file_1 = 'im1.jpg'
image_file_2 = 'im2.jpg'

# Construct full image file paths
image_path_1 = image_folder + image_file_1
image_path_2 = image_folder + image_file_2

# Run batched inference on a list of images
results = model([image_path_1, image_path_2])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs

    # Print box coordinates
    print("Box coordinates:")
    for box in boxes:
        print(box)

    # Display result with boxes
    result.plot()
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# 0: 640x640 3 persons, 131.1ms
# 1: 640x640 4 persons, 131.1ms
# Speed: 2.8ms preprocess, 131.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8213])
# data: tensor([[ 35.3474,  56.4592,  94.0518, 159.4454,   0.8213,   0.0000]])
# id: None
# is_track: False
# orig_shape: (184, 275)
# shape: torch.Size([1, 6])
# xywh: tensor([[ 64.6996, 107.9523,  58.7044, 102.9861]])
# xywhn: tensor([[0.2353, 0.5867, 0.2135, 0.5597]])
# xyxy: tensor([[ 35.3474,  56.4592,  94.0518, 159.4454]])
# xyxyn: tensor([[0.1285, 0.3068, 0.3420, 0.8666]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7709])
# data: tensor([[153.5596,  90.2625, 181.7097, 143.3668,   0.7709,   0.0000]])
# id: None
# is_track: False
# orig_shape: (184, 275)
# shape: torch.Size([1, 6])
# xywh: tensor([[167.6347, 116.8146,  28.1501,  53.1043]])
# xywhn: tensor([[0.6096, 0.6349, 0.1024, 0.2886]])
# xyxy: tensor([[153.5596,  90.2625, 181.7097, 143.3668]])
# xyxyn: tensor([[0.5584, 0.4906, 0.6608, 0.7792]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6509])
# data: tensor([[205.5987,  99.0372, 220.5855, 144.0199,   0.6509,   0.0000]])
# id: None
# is_track: False
# orig_shape: (184, 275)
# shape: torch.Size([1, 6])
# xywh: tensor([[213.0921, 121.5286,  14.9868,  44.9827]])
# xywhn: tensor([[0.7749, 0.6605, 0.0545, 0.2445]])
# xyxy: tensor([[205.5987,  99.0372, 220.5855, 144.0199]])
# xyxyn: tensor([[0.7476, 0.5382, 0.8021, 0.7827]])
# Box coordinates:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8272])
# data: tensor([[176.4081, 389.5300, 279.1333, 515.0812,   0.8272,   0.0000]])
# id: None
# is_track: False
# orig_shape: (731, 1300)
# shape: torch.Size([1, 6])
# xywh: tensor([[227.7707, 452.3056, 102.7252, 125.5512]])
# xywhn: tensor([[0.1752, 0.6187, 0.0790, 0.1718]])
# xyxy: tensor([[176.4081, 389.5300, 279.1333, 515.0812]])
# xyxyn: tensor([[0.1357, 0.5329, 0.2147, 0.7046]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.8212])
# data: tensor([[442.0331, 453.9737, 542.3865, 570.0051,   0.8212,   0.0000]])
# id: None
# is_track: False
# orig_shape: (731, 1300)
# shape: torch.Size([1, 6])
# xywh: tensor([[492.2098, 511.9894, 100.3534, 116.0314]])
# xywhn: tensor([[0.3786, 0.7004, 0.0772, 0.1587]])
# xyxy: tensor([[442.0331, 453.9737, 542.3865, 570.0051]])
# xyxyn: tensor([[0.3400, 0.6210, 0.4172, 0.7798]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.7963])
# data: tensor([[135.5656, 202.0416, 245.3554, 334.9522,   0.7963,   0.0000]])
# id: None
# is_track: False
# orig_shape: (731, 1300)
# shape: torch.Size([1, 6])
# xywh: tensor([[190.4605, 268.4969, 109.7898, 132.9106]])
# xywhn: tensor([[0.1465, 0.3673, 0.0845, 0.1818]])
# xyxy: tensor([[135.5656, 202.0416, 245.3554, 334.9522]])
# xyxyn: tensor([[0.1043, 0.2764, 0.1887, 0.4582]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.])
# conf: tensor([0.6075])
# data: tensor([[5.5828e+02, 3.4998e+02, 6.6755e+02, 4.6291e+02, 6.0745e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (731, 1300)
# shape: torch.Size([1, 6])
# xywh: tensor([[612.9159, 406.4447, 109.2729, 112.9288]])
# xywhn: tensor([[0.4715, 0.5560, 0.0841, 0.1545]])
# xyxy: tensor([[558.2795, 349.9803, 667.5524, 462.9091]])
# xyxyn: tensor([[0.4294, 0.4788, 0.5135, 0.6333]])

# %% [markdown]
# # 코드 개선

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load a pretrained YOLO model
model = YOLO("yolov8n.pt")  # COCO dataset으로 pretrained된 모델을 불러옴

# Define image file path
image_path = "C:\\DEV\\SamsungElectronics_Gumi\\datasets\\YOLO\\im2.jpg"

# Use the model to perform object detection
results = model.predict(image_path)

# Print results for debugging
print(results[0])
print()
print(results[0].boxes)  # 좌상단 좌표, 우하단 좌표, confidence score, class id

# Plot the result
res_plotted = results[0].plot()  # 결과 이미지를 그립니다 (bounding box 등)

# Convert BGR (OpenCV format) to RGB (matplotlib format)
res_plotted_rgb = cv2.cvtColor(res_plotted, cv2.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.figure(figsize=(12, 12))
plt.imshow(res_plotted_rgb)
plt.axis('off')  # 축을 숨깁니다
plt.show()
# Out:
# image 1/1 C:\DEV\SamsungElectronics_Gumi\datasets\YOLO\im2.jpg: 384x640 4 persons, 87.5ms
# Speed: 2.0ms preprocess, 87.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[172, 157, 141],
#         [163, 148, 132],
#         [178, 163, 147],
#         ...,
#         [189, 173, 157],
#         [186, 170, 154],
#         [184, 168, 152]],
#
#        [[174, 159, 143],
#         [165, 150, 134],
#         [174, 159, 143],
#         ...,
#         [191, 175, 159],
#         [190, 174, 158],
#         [189, 173, 157]],
#
#        [[168, 153, 137],
#         [165, 150, 134],
#         [175, 160, 144],
#         ...,
#         [192, 176, 160],
#         [191, 175, 159],
#         [190, 174, 158]],
#
#        ...,
#
#        [[180, 162, 151],
#         [170, 152, 141],
#         [171, 153, 142],
#         ...,
#         [150, 134, 122],
#         [152, 136, 124],
#         [155, 139, 127]],
#
#        [[173, 155, 144],
#         [164, 146, 135],
#         [166, 148, 137],
#         ...,
#         [150, 134, 122],
#         [152, 136, 124],
#         [155, 139, 127]],
#
#        [[168, 150, 139],
#         [161, 143, 132],
#         [165, 147, 136],
#         ...,
#         [150, 134, 122],
#         [152, 136, 124],
#         [155, 139, 127]]], dtype=uint8)
# orig_shape: (731, 1300)
# path: 'C:\\DEV\\SamsungElectronics_Gumi\\datasets\\YOLO\\im2.jpg'
# probs: None
# save_dir: 'runs\\detect\\predict'
# speed: {'preprocess': 1.993417739868164, 'inference': 87.49866485595703, 'postprocess': 1.993417739868164}
#
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0., 0., 0., 0.])
# conf: tensor([0.8194, 0.8157, 0.7971, 0.5843])
# data: tensor([[1.7640e+02, 3.8956e+02, 2.7913e+02, 5.1514e+02, 8.1941e-01, 0.0000e+00],
#         [4.4208e+02, 4.5400e+02, 5.4239e+02, 5.7004e+02, 8.1573e-01, 0.0000e+00],
#         [1.3561e+02, 2.0208e+02, 2.4536e+02, 3.3502e+02, 7.9706e-01, 0.0000e+00],
#         [5.5826e+02, 3.5016e+02, 6.6757e+02, 4.6303e+02, 5.8428e-01, 0.0000e+00]])
# id: None
# is_track: False
# orig_shape: (731, 1300)
# shape: torch.Size([4, 6])
# xywh: tensor([[227.7627, 452.3520, 102.7299, 125.5793],
#         [492.2344, 512.0232, 100.3069, 116.0375],
#         [190.4862, 268.5547, 109.7573, 132.9398],
#         [612.9167, 406.5919, 109.3121, 112.8716]])
# xywhn: tensor([[0.1752, 0.6188, 0.0790, 0.1718],
#         [0.3786, 0.7004, 0.0772, 0.1587],
#         [0.1465, 0.3674, 0.0844, 0.1819],
#         [0.4715, 0.5562, 0.0841, 0.1544]])
# xyxy: tensor([[176.3978, 389.5623, 279.1277, 515.1417],
#         [442.0810, 454.0044, 542.3879, 570.0419],
#         [135.6076, 202.0848, 245.3649, 335.0245],
#         [558.2607, 350.1561, 667.5728, 463.0277]])
# xyxyn: tensor([[0.1357, 0.5329, 0.2147, 0.7047],
#         [0.3401, 0.6211, 0.4172, 0.7798],
#         [0.1043, 0.2764, 0.1887, 0.4583],
#         [0.4294, 0.4790, 0.5135, 0.6334]])
